# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np  #0 white 1 black 2 chinese 3 indian 4 hispanic
import pandas as pd
import cv2
import glob
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import asarray 
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, SubsetRandomSampler
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.transforms import ToPILImage, ToTensor
import re
import os
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.metrics import classification_report
import gc
torch.cuda.empty_cache()
gc.collect()

#for dirname, _, filenames in os.walk('/kaggle/input/utkface-new/UTKFace'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))   
        
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 46

# %%
DATA_DIR = "/kaggle/input/utkface-new/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))
attributes = list(map(parse_filepath, files))
# Out:
# /kaggle/input/utkface-new/UTKFace/61_1_20170109142408075.jpg.chip.jpg
# /kaggle/input/utkface-new/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# /kaggle/input/utkface-new/UTKFace/39_1_20170116174525125.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  26.0    male   asian  /kaggle/input/utkface-new/UTKFace/26_0_2_20170...
# 1  22.0  female   black  /kaggle/input/utkface-new/UTKFace/22_1_1_20170...
# 2  21.0  female  indian  /kaggle/input/utkface-new/UTKFace/21_1_3_20170...
# 3  28.0    male   white  /kaggle/input/utkface-new/UTKFace/28_0_0_20170...
# 4  17.0  female  others  /kaggle/input/utkface-new/UTKFace/17_1_4_20170...

# %%
# Under-sample the 'white' class
white_df = df[df['race'] == 'white']
non_white_df = df[df['race'] != 'white']

# %%
# Set the desired count, equalize it to the count of the 'black' class for 
desired_white_count = df[df['race'] == 'black'].shape[0]
white_df = white_df.sample(n=desired_white_count, random_state=42)

# Under-sample age values of 26
age_26_df = df[df['age'] == 26]
non_age_26_df = df[df['age'] != 26]

# Set the desired count, median of the age counts 
median_age_count = int(df['age'].value_counts().median())
age_26_df = age_26_df.sample(n=median_age_count, random_state=42)

# %%
# Concatenate separate DataFrames back together
df = pd.concat([white_df, non_white_df, age_26_df, non_age_26_df])

# %%
# Shuffle the DataFrame rows
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.describe()
# Out:
#                 age
# count  39808.000000
# mean      33.028311
# std       19.960382
# min        1.000000
# 25%       22.000000
# 50%       30.000000
# 75%       45.000000
# max      116.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='race,gender'>

# %%
df['age'].hist()
# Out:
# <Axes: >

# %%
df['age'].describe()
df = df[(df['age'] > 10) & (df['age'] < 70)]

# %%
p = np.random.permutation(len(df))
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# (15583, 6679, 9542, 69.0)

# %%
class UTKFaceDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.iloc[idx, 3]
        image = Image.open(img_name)
        age = self.df.iloc[idx, 0] / max_age
        race = torch.zeros(len(RACE_ID_MAP))
        race[self.df.iloc[idx, 5]] = 1
        gender = torch.zeros(2)
        gender[self.df.iloc[idx, 4]] = 1

        if self.transform:
            image = self.transform(image)

        return image, age, race, gender

transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

dataset = UTKFaceDataset(df, transform)

train_loader = DataLoader(dataset, batch_size=64, sampler=SubsetRandomSampler(train_idx))
valid_loader = DataLoader(dataset, batch_size=64, sampler=SubsetRandomSampler(valid_idx))
test_loader = DataLoader(dataset, batch_size=128, sampler=SubsetRandomSampler(test_idx))

# %%
# from torchvision.models import mobilenet_v2

# class MobileNetV2Model(nn.Module):
#     def __init__(self):
#         super(MobileNetV2Model, self).__init__()
        
#         # MobileNet V2 backbone
#         self.backbone = mobilenet_v2(pretrained=True).features

#         # Extra CNN layers for age
#         self.age_cnn = nn.Sequential(
#             self.conv_block(1280, 192),
#             self.conv_block(192, 128),
#             self.conv_block(128, 64),
#             nn.BatchNorm2d(64),
#             nn.ReLU(),
#             nn.AdaptiveAvgPool2d((1, 1))
#         )
#         self.fc1_age = nn.Sequential(
#             nn.Linear(64, 128), 
#             nn.ReLU(), 
#             nn.Linear(128, 1)
#         )

#         # Extra CNN layers for race (ethnicity)
#         self.race_cnn = nn.Sequential(
#             self.conv_block(1280, 192),
#             self.conv_block(192, 128),
#             self.conv_block(128, 64),
#             nn.AdaptiveAvgPool2d((1, 1))
#         )
#         self.fc1_race = nn.Sequential(
#             nn.Linear(64, 256),
#             nn.ReLU(),
#             nn.Dropout(0.35),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Dropout(0.35),
#             nn.Linear(128, len(RACE_ID_MAP))
#         )

#         # Extra CNN layers for gender
#         self.gender_cnn = nn.Sequential(
#             self.conv_block(1280, 192),
#             self.conv_block(192, 128),
#             self.conv_block(128, 64),
#             nn.AdaptiveAvgPool2d((1, 1))
#         )
#         self.fc1_gender = nn.Sequential(
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(0.43),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(0.43),
#             nn.Linear(64, 2)
#         )

#     def conv_block(self, in_channels, out_channels):
#         layers = [
#             nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
#             nn.BatchNorm2d(out_channels),
#             nn.ReLU()
#         ]
#         return nn.Sequential(*layers)

#     def forward(self, x):
#         x = self.backbone(x)
#         age_x = self.age_cnn(x)
#         age_x = torch.flatten(age_x, 1)
#         age = torch.sigmoid(self.fc1_age(age_x))
        
#         race_x = self.race_cnn(x)
#         race_x = torch.flatten(race_x, 1)
#         race = F.softmax(self.fc1_race(race_x), dim=1)
        
#         gender_x = self.gender_cnn(x)
#         gender_x = torch.flatten(gender_x, 1)
#         gender = torch.sigmoid(self.fc1_gender(gender_x))
        
#         return age, race, gender

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = MobileNetV2Model().to(device)
# model = model.float()
# criterion_age = nn.MSELoss()
# criterion_race = nn.CrossEntropyLoss()
# criterion_gender = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import mobilenet_v2

class MobileNetV2Model(nn.Module):
    def __init__(self, num_race_classes, dropout_rate=0.2):
        super(MobileNetV2Model, self).__init__()
        
        # MobileNet V2 backbone
        self.backbone = mobilenet_v2(pretrained=True).features

        # Extra CNN layers for age
        self.age_cnn = nn.Sequential(
            self.conv_block(1280, 192),
            self.conv_block(192, 128),
            self.conv_block(128, 64),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc1_age = nn.Sequential(
            nn.Linear(64, 128), 
            nn.ReLU(), 
            nn.Linear(128, 1)
        )

        # Extra CNN layers for race (ethnicity)
        self.race_cnn = nn.Sequential(
            self.conv_block(1280, 192),
            self.conv_block(192, 128),
            self.conv_block(128, 64),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc1_race = nn.Sequential(
            nn.Linear(64, 256),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, num_race_classes)
        )

        # Extra CNN layers for gender
        self.gender_cnn = nn.Sequential(
            self.conv_block(1280, 192),
            self.conv_block(192, 128),
            self.conv_block(128, 64),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc1_gender = nn.Sequential(
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 2)
        )

    def conv_block(self, in_channels, out_channels):
        layers = [
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        ]
        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.backbone(x)
        age_x = self.age_cnn(x)
        age_x = torch.flatten(age_x, 1)
        age = torch.sigmoid(self.fc1_age(age_x))
        
        race_x = self.race_cnn(x)
        race_x = torch.flatten(race_x, 1)
        race = F.softmax(self.fc1_race(race_x), dim=1)
        
        gender_x = self.gender_cnn(x)
        gender_x = torch.flatten(gender_x, 1)
        gender = torch.sigmoid(self.fc1_gender(gender_x))
        
        return age, race, gender

# Hyperparameters
num_race_classes = len(RACE_ID_MAP)
dropout_rate = 0.5
learning_rate = 0.0001

# Initialize model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MobileNetV2Model(num_race_classes, dropout_rate).to(device)
model = model.float()

# Loss functions
criterion_age = nn.MSELoss()
criterion_race = nn.CrossEntropyLoss()
criterion_gender = nn.CrossEntropyLoss()

# Optimizer with weight decay
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)

# Learning rate scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.9)

# %%
# class MobileNetV3Model(nn.Module):
#     def __init__(self):
#         super(MobileNetV3Model, self).__init__()
        
#         # MobileNet V3 backbone
#         self.backbone = models.mobilenet_v3_small(pretrained=True)
#         self.backbone = nn.Sequential(*list(self.backbone.children())[:-1])

#         # Extra CNN layers for age
#         self.age_cnn = nn.Sequential(
#             self.conv_block(576, 192),
#             self.conv_block(192, 128),
#             self.conv_block(128, 64),
# #             nn.MaxPool2d(2),
#             nn.BatchNorm2d(64),
#             nn.ReLU(),
#             nn.AdaptiveAvgPool2d((1, 1))
#         )
#         self.fc1_age = nn.Sequential(
#             nn.Linear(64, 128), 
#             nn.ReLU(), 
#             nn.Linear(128, 1)
#         )

#         # Extra CNN layers for race (ethnicity)
#         self.race_cnn = nn.Sequential(
#             self.conv_block(576, 192),
# #             nn.MaxPool2d(2),
#             self.conv_block(192, 128),
# #             nn.MaxPool2d(2),
#             self.conv_block(128, 64),
# #             nn.MaxPool2d(2),
#             nn.AdaptiveAvgPool2d((1, 1))
#         )
#         self.fc1_race = nn.Sequential(
#             nn.Linear(64, 256),
#             nn.ReLU(),
#             nn.Dropout(0.35),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Dropout(0.35),
#             nn.Linear(128, len(RACE_ID_MAP))
#         )

#         # Extra CNN layers for gender
#         self.gender_cnn = nn.Sequential(
#             self.conv_block(576, 192),
#             self.conv_block(192, 128),
#             self.conv_block(128, 64),
# #             nn.MaxPool2d(2),
#             nn.AdaptiveAvgPool2d((1, 1))
#         )
#         self.fc1_gender = nn.Sequential(
#             nn.Linear(64, 128),
#             nn.ReLU(),
#             nn.Dropout(0.43),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Dropout(0.43),
#             nn.Linear(64, 2)
#         )

#     def conv_block(self, in_channels, out_channels):
#         layers = [
#             nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
#             nn.BatchNorm2d(out_channels),
#             nn.ReLU(),
# #             nn.AdaptiveAvgPool2d((1,1))
#         ]
#         return nn.Sequential(*layers)

#     def forward(self, x):
#         x = self.backbone(x)
# # #         print("Shape after backbone:", x.shape)
# #         age_x = self.age_cnn[0](x)
# #         print("Shape after first conv_block in age_cnn:", age_x.shape)
    
# #         age_x = self.age_cnn[1](age_x)
# #         print("Shape after second conv_block in age_cnn:", age_x.shape)
    
# #         age_x = self.age_cnn[2](age_x)
# #         print("Shape after third conv_block in age_cnn:", age_x.shape)
    
# #         age_x = self.age_cnn[3](age_x)
# #         print("Shape after MaxPool2d in age_cnn:", age_x.shape)
    
# #         age_x = self.age_cnn[4](age_x)
# #         print("Shape after BatchNorm2d in age_cnn:", age_x.shape)

# #         age_x = self.age_cnn[5](age_x)
# #         print("Shape after ReLU in age_cnn:", age_x.shape)
    
# #         age_x = self.age_cnn[6](age_x)
# #         print("Shape after AdaptiveAvgPool2d in age_cnn:", age_x.shape)
#         age_x = self.age_cnn(x)
#         age_x = torch.flatten(age_x, 1)
#         age = torch.sigmoid(self.fc1_age(age_x))
        
#         race_x = self.race_cnn(x)
#         race_x = torch.flatten(race_x, 1)
#         race = F.softmax(self.fc1_race(race_x), dim=1)
        
#         gender_x = self.gender_cnn(x)
#         gender_x = torch.flatten(gender_x, 1)
#         gender = torch.sigmoid(self.fc1_gender(gender_x))#,dim=1)
        
#         return age, race, gender

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model =  MobileNetV3Model().to(device)
# model = model.float()
# criterion_age = nn.MSELoss()
# criterion_race = nn.CrossEntropyLoss()      #loss together backward or individually backward
# criterion_gender = nn.CrossEntropyLoss()
# # optimizer = torch.optim.RMSprop(model.parameters(),lr=0.0001)
# optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)

# %%
import time
import matplotlib.pyplot as plt

# Initialization
num_epochs = 100

# Lists to hold running losses for plotting
train_loss_age = []
train_loss_race = []
train_loss_gender = []
train_total_loss = []

# Lists to hold validation losses
valid_loss_age = []
valid_loss_race = []
valid_loss_gender = []
valid_total_loss = []

# Start the timer
start_time = time.time()

for epoch in range(num_epochs):
    model.train()
    epoch_train_loss_age = 0
    epoch_train_loss_race = 0
    epoch_train_loss_gender = 0
    epoch_train_total_loss = 0
    total_samples = 0
    
    for images, ages, races, genders in train_loader:
        images, ages, races, genders = images.float().to(device), ages.float().to(device), races.float().to(device), genders.float().to(device)
        
        optimizer.zero_grad()
        age_preds, race_preds, gender_preds = model(images)
        age_preds = age_preds.squeeze(1)
        
        loss_age = criterion_age(age_preds, ages)
        loss_race = criterion_race(race_preds, torch.argmax(races, dim=1))
        loss_gender = criterion_gender(gender_preds, torch.argmax(genders, dim=1))
        loss = 2*loss_age + 1.5*loss_race + loss_gender  
        
        loss.backward()
        optimizer.step()
        
        # Update the running losses
        epoch_train_loss_age += loss_age.item() * len(images)
        epoch_train_loss_race += loss_race.item() * len(images)
        epoch_train_loss_gender += loss_gender.item() * len(images)
        epoch_train_total_loss += loss.item() * len(images)
        total_samples += len(images)
    
    # Compute validation loss
    model.eval()
    epoch_valid_loss_age = 0
    epoch_valid_loss_race = 0
    epoch_valid_loss_gender = 0
    epoch_valid_total_loss = 0
    valid_samples = 0
    
    with torch.no_grad():
        for images, ages, races, genders in valid_loader:
            images, ages, races, genders = images.float().to(device), ages.float().to(device), races.float().to(device), genders.float().to(device)
            
            age_preds, race_preds, gender_preds = model(images)
            age_preds = age_preds.squeeze(1)
            
            loss_age = criterion_age(age_preds, ages)
            loss_race = criterion_race(race_preds, torch.argmax(races, dim=1))
            loss_gender = criterion_gender(gender_preds, torch.argmax(genders, dim=1))
            loss = 2*loss_age + 1.5*loss_race + loss_gender 
            
            epoch_valid_loss_age += loss_age.item() * len(images)
            epoch_valid_loss_race += loss_race.item() * len(images)
            epoch_valid_loss_gender += loss_gender.item() * len(images)
            epoch_valid_total_loss += loss.item() * len(images)
            valid_samples += len(images)
    
    # Average the losses over the epoch for training
    avg_train_loss_age = epoch_train_loss_age / total_samples
    avg_train_loss_race = epoch_train_loss_race / total_samples
    avg_train_loss_gender = epoch_train_loss_gender / total_samples
    avg_train_total_loss = epoch_train_total_loss / total_samples
    
    # Average the losses over the epoch for validation
    avg_valid_loss_age = epoch_valid_loss_age / valid_samples
    avg_valid_loss_race = epoch_valid_loss_race / valid_samples
    avg_valid_loss_gender = epoch_valid_loss_gender / valid_samples
    avg_valid_total_loss = epoch_valid_total_loss / valid_samples
    
    # Append the average losses for plotting later (training)
    train_loss_age.append(avg_train_loss_age)
    train_loss_race.append(avg_train_loss_race)
    train_loss_gender.append(avg_train_loss_gender)
    train_total_loss.append(avg_train_total_loss)
    
    # Append the average losses for plotting later (validation)
    valid_loss_age.append(avg_valid_loss_age)
    valid_loss_race.append(avg_valid_loss_race)
    valid_loss_gender.append(avg_valid_loss_gender)
    valid_total_loss.append(avg_valid_total_loss)

    # Print out the losses for training and validation
    print(f"Epoch [{epoch+1}/{num_epochs}] => Train Age Loss: {avg_train_loss_age:.9f}, Train Race Loss: {avg_train_loss_race:.9f}, Train Gender Loss: {avg_train_loss_gender:.9f}, Train Total Loss: {avg_train_total_loss:.9f}")
    print(f"Epoch [{epoch+1}/{num_epochs}] => Valid Age Loss: {avg_valid_loss_age:.9f}, Valid Race Loss: {avg_valid_loss_race:.9f}, Valid Gender Loss: {avg_valid_loss_gender:.9f}, Valid Total Loss: {avg_valid_total_loss:.9f}")

# End the timer
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Training took {elapsed_time:.2f} seconds")
# Out:
# Epoch [1/100] => Train Age Loss: 0.017446574, Train Race Loss: 1.380914264, Train Gender Loss: 0.537279436, Train Total Loss: 2.643543980
# Epoch [1/100] => Valid Age Loss: 0.012849768, Valid Race Loss: 1.158292277, Valid Gender Loss: 0.399124613, Valid Total Loss: 2.162262565
# Epoch [2/100] => Train Age Loss: 0.012653504, Train Race Loss: 1.126824728, Train Gender Loss: 0.378551830, Train Total Loss: 2.094095924
# Epoch [2/100] => Valid Age Loss: 0.012051136, Valid Race Loss: 1.105362103, Valid Gender Loss: 0.354601527, Valid Total Loss: 2.036746955
# Epoch [3/100] => Train Age Loss: 0.011357860, Train Race Loss: 1.084799221, Train Gender Loss: 0.357369264, Train Total Loss: 2.007283808
# Epoch [3/100] => Valid Age Loss: 0.011699626, Valid Race Loss: 1.097019977, Valid Gender Loss: 0.355199556, Valid Total Loss: 2.024128779
# Epoch [4/100] => Train Age Loss: 0.010588712, Train Race Loss: 1.074820837, Train Gender Loss: 0.349574448, Train Total Loss: 1.982983128
# Epoch [4/100] => Valid Age Loss: 0.011399209, Valid Race Loss: 1.092981155, Valid Gender Loss: 0.355824919, Valid Total Loss: 2.018095077
# Epoch [5/100] => Train Age Loss: 0.009834344, Train Race Loss: 1.061627677, Train Gender Loss: 0.345747366, Train Total Loss: 1.957857573
# Epoch [5/100] => Valid Age Loss: 0.011608935, Valid Race Loss: 1.085781777, Valid Gender Loss: 0.353422915, Valid Total Loss: 2.005313446
# Epoch [6/100] => Train Age Loss: 0.009293582, Train Race Loss: 1.049733509, Train Gender Loss: 0.344601032, Train Total Loss: 1.937788463
# Epoch [6/100] => Valid Age Loss: 0.010723755, Valid Race Loss: 1.079474156, Valid Gender Loss: 0.351285031, Valid Total Loss: 1.991943776
# Epoch [7/100] => Train Age Loss: 0.008911834, Train Race Loss: 1.041948595, Train Gender Loss: 0.340022351, Train Total Loss: 1.920768911
# Epoch [7/100] => Valid Age Loss: 0.010499131, Valid Race Loss: 1.079638091, Valid Gender Loss: 0.349519080, Valid Total Loss: 1.989974478
# Epoch [8/100] => Train Age Loss: 0.008331858, Train Race Loss: 1.039729071, Train Gender Loss: 0.338904213, Train Total Loss: 1.915161535
# Epoch [8/100] => Valid Age Loss: 0.010337980, Valid Race Loss: 1.074240668, Valid Gender Loss: 0.345562609, Valid Total Loss: 1.977599585
# Epoch [9/100] => Train Age Loss: 0.008032019, Train Race Loss: 1.030210451, Train Gender Loss: 0.334254536, Train Total Loss: 1.895634249
# Epoch [9/100] => Valid Age Loss: 0.010315063, Valid Race Loss: 1.068498518, Valid Gender Loss: 0.346968218, Valid Total Loss: 1.970346114
# Epoch [10/100] => Train Age Loss: 0.007736512, Train Race Loss: 1.029937394, Train Gender Loss: 0.333293899, Train Total Loss: 1.893673011
# Epoch [10/100] => Valid Age Loss: 0.010521611, Valid Race Loss: 1.072683632, Valid Gender Loss: 0.345504952, Valid Total Loss: 1.975573618
# Epoch [11/100] => Train Age Loss: 0.007497450, Train Race Loss: 1.026642410, Train Gender Loss: 0.331911448, Train Total Loss: 1.886869966
# Epoch [11/100] => Valid Age Loss: 0.009766489, Valid Race Loss: 1.068633530, Valid Gender Loss: 0.348558651, Valid Total Loss: 1.971041924
# Epoch [12/100] => Train Age Loss: 0.007297153, Train Race Loss: 1.024925347, Train Gender Loss: 0.331834925, Train Total Loss: 1.883817251
# Epoch [12/100] => Valid Age Loss: 0.010375536, Valid Race Loss: 1.068896063, Valid Gender Loss: 0.343823155, Valid Total Loss: 1.967918308
# Epoch [13/100] => Train Age Loss: 0.007172934, Train Race Loss: 1.021097335, Train Gender Loss: 0.331033331, Train Total Loss: 1.877025195
# Epoch [13/100] => Valid Age Loss: 0.009831688, Valid Race Loss: 1.059570530, Valid Gender Loss: 0.342863280, Valid Total Loss: 1.951882464
# Epoch [14/100] => Train Age Loss: 0.006733941, Train Race Loss: 1.020373742, Train Gender Loss: 0.331043835, Train Total Loss: 1.875072333
# Epoch [14/100] => Valid Age Loss: 0.009420408, Valid Race Loss: 1.062965913, Valid Gender Loss: 0.347063668, Valid Total Loss: 1.960353351
# Epoch [15/100] => Train Age Loss: 0.006312441, Train Race Loss: 1.013033133, Train Gender Loss: 0.330778701, Train Total Loss: 1.862953291
# Epoch [15/100] => Valid Age Loss: 0.010036256, Valid Race Loss: 1.061864090, Valid Gender Loss: 0.343131475, Valid Total Loss: 1.956000129
# Epoch [16/100] => Train Age Loss: 0.005931463, Train Race Loss: 1.008036522, Train Gender Loss: 0.327905807, Train Total Loss: 1.851823513
# Epoch [16/100] => Valid Age Loss: 0.009194214, Valid Race Loss: 1.055118933, Valid Gender Loss: 0.342856309, Valid Total Loss: 1.943923127
# Epoch [17/100] => Train Age Loss: 0.005876460, Train Race Loss: 1.002335193, Train Gender Loss: 0.329222559, Train Total Loss: 1.844478268
# Epoch [17/100] => Valid Age Loss: 0.009822462, Valid Race Loss: 1.049888413, Valid Gender Loss: 0.344416004, Valid Total Loss: 1.938893544
# Epoch [18/100] => Train Age Loss: 0.006207842, Train Race Loss: 0.996763443, Train Gender Loss: 0.327069149, Train Total Loss: 1.834629997
# Epoch [18/100] => Valid Age Loss: 0.009491731, Valid Race Loss: 1.054604593, Valid Gender Loss: 0.346283212, Valid Total Loss: 1.947173571
# Epoch [19/100] => Train Age Loss: 0.006248785, Train Race Loss: 0.994488202, Train Gender Loss: 0.327732412, Train Total Loss: 1.831962283
# Epoch [19/100] => Valid Age Loss: 0.009942929, Valid Race Loss: 1.050861248, Valid Gender Loss: 0.345916852, Valid Total Loss: 1.942094588
# Epoch [20/100] => Train Age Loss: 0.006332957, Train Race Loss: 0.993108399, Train Gender Loss: 0.328466455, Train Total Loss: 1.830794969
# Epoch [20/100] => Valid Age Loss: 0.009528260, Valid Race Loss: 1.050124452, Valid Gender Loss: 0.346005119, Valid Total Loss: 1.940248321
# Epoch [21/100] => Train Age Loss: 0.006108312, Train Race Loss: 0.986835333, Train Gender Loss: 0.328809999, Train Total Loss: 1.821279625
# Epoch [21/100] => Valid Age Loss: 0.009399046, Valid Race Loss: 1.051502007, Valid Gender Loss: 0.342988946, Valid Total Loss: 1.939040045
# Epoch [22/100] => Train Age Loss: 0.006176221, Train Race Loss: 0.984517297, Train Gender Loss: 0.327727852, Train Total Loss: 1.816856235
# Epoch [22/100] => Valid Age Loss: 0.009456623, Valid Race Loss: 1.043108052, Valid Gender Loss: 0.347042768, Valid Total Loss: 1.930618078
# Epoch [23/100] => Train Age Loss: 0.006026921, Train Race Loss: 0.983212983, Train Gender Loss: 0.325585871, Train Total Loss: 1.812459192
# Epoch [23/100] => Valid Age Loss: 0.009480475, Valid Race Loss: 1.060210296, Valid Gender Loss: 0.345234278, Valid Total Loss: 1.954510664
# Epoch [24/100] => Train Age Loss: 0.005870771, Train Race Loss: 0.983352702, Train Gender Loss: 0.327243544, Train Total Loss: 1.814014139
# Epoch [24/100] => Valid Age Loss: 0.009657931, Valid Race Loss: 1.054006176, Valid Gender Loss: 0.343310338, Valid Total Loss: 1.943635475
# Epoch [25/100] => Train Age Loss: 0.006106687, Train Race Loss: 0.980212995, Train Gender Loss: 0.326019095, Train Total Loss: 1.808551965
# Epoch [25/100] => Valid Age Loss: 0.010044494, Valid Race Loss: 1.053686349, Valid Gender Loss: 0.340980576, Valid Total Loss: 1.941599098
# Epoch [26/100] => Train Age Loss: 0.005586869, Train Race Loss: 0.968843384, Train Gender Loss: 0.326869725, Train Total Loss: 1.791308544
# Epoch [26/100] => Valid Age Loss: 0.009169032, Valid Race Loss: 1.046748657, Valid Gender Loss: 0.345214337, Valid Total Loss: 1.933675384
# Epoch [27/100] => Train Age Loss: 0.005441065, Train Race Loss: 0.970066782, Train Gender Loss: 0.325007971, Train Total Loss: 1.790990270
# Epoch [27/100] => Valid Age Loss: 0.009700831, Valid Race Loss: 1.044880275, Valid Gender Loss: 0.342831196, Valid Total Loss: 1.929553265
# Epoch [28/100] => Train Age Loss: 0.005357672, Train Race Loss: 0.963606960, Train Gender Loss: 0.324558353, Train Total Loss: 1.780684129
# Epoch [28/100] => Valid Age Loss: 0.009840129, Valid Race Loss: 1.044751521, Valid Gender Loss: 0.341064339, Valid Total Loss: 1.927871899
# Epoch [29/100] => Train Age Loss: 0.005393605, Train Race Loss: 0.967760381, Train Gender Loss: 0.326874000, Train Total Loss: 1.789301784
# Epoch [29/100] => Valid Age Loss: 0.009944121, Valid Race Loss: 1.049416488, Valid Gender Loss: 0.346995514, Valid Total Loss: 1.941008484
# Epoch [30/100] => Train Age Loss: 0.005592484, Train Race Loss: 0.967482220, Train Gender Loss: 0.325746061, Train Total Loss: 1.788154363
# Epoch [30/100] => Valid Age Loss: 0.009688739, Valid Race Loss: 1.037949563, Valid Gender Loss: 0.340828903, Valid Total Loss: 1.917130723
# Epoch [31/100] => Train Age Loss: 0.005098983, Train Race Loss: 0.958584685, Train Gender Loss: 0.325318912, Train Total Loss: 1.773393905
# Epoch [31/100] => Valid Age Loss: 0.009115024, Valid Race Loss: 1.035530665, Valid Gender Loss: 0.340221848, Valid Total Loss: 1.911747900
# Epoch [32/100] => Train Age Loss: 0.004952979, Train Race Loss: 0.957536616, Train Gender Loss: 0.324114908, Train Total Loss: 1.770325789
# Epoch [32/100] => Valid Age Loss: 0.009302316, Valid Race Loss: 1.034990038, Valid Gender Loss: 0.339284732, Valid Total Loss: 1.910374422
# Epoch [33/100] => Train Age Loss: 0.005013793, Train Race Loss: 0.956776494, Train Gender Loss: 0.324544320, Train Total Loss: 1.769736651
# Epoch [33/100] => Valid Age Loss: 0.009521987, Valid Race Loss: 1.036448392, Valid Gender Loss: 0.341423673, Valid Total Loss: 1.915140226
# Epoch [34/100] => Train Age Loss: 0.004841943, Train Race Loss: 0.954708747, Train Gender Loss: 0.324792376, Train Total Loss: 1.766539384
# Epoch [34/100] => Valid Age Loss: 0.008980785, Valid Race Loss: 1.029564597, Valid Gender Loss: 0.337940954, Valid Total Loss: 1.900249422
# Epoch [35/100] => Train Age Loss: 0.004821965, Train Race Loss: 0.956727725, Train Gender Loss: 0.323571534, Train Total Loss: 1.768307050
# Epoch [35/100] => Valid Age Loss: 0.009558187, Valid Race Loss: 1.030650109, Valid Gender Loss: 0.338633688, Valid Total Loss: 1.903725215
# Epoch [36/100] => Train Age Loss: 0.005217241, Train Race Loss: 0.958739531, Train Gender Loss: 0.327098637, Train Total Loss: 1.775642416
# Epoch [36/100] => Valid Age Loss: 0.009220625, Valid Race Loss: 1.036281344, Valid Gender Loss: 0.343698225, Valid Total Loss: 1.916561497
# Epoch [37/100] => Train Age Loss: 0.004941846, Train Race Loss: 0.955991589, Train Gender Loss: 0.325624417, Train Total Loss: 1.769495502
# Epoch [37/100] => Valid Age Loss: 0.009583536, Valid Race Loss: 1.048861657, Valid Gender Loss: 0.339157656, Valid Total Loss: 1.931617218
# Epoch [38/100] => Train Age Loss: 0.005005704, Train Race Loss: 0.957988396, Train Gender Loss: 0.326316553, Train Total Loss: 1.773310559
# Epoch [38/100] => Valid Age Loss: 0.010190235, Valid Race Loss: 1.043469576, Valid Gender Loss: 0.341050214, Valid Total Loss: 1.926635052
# Epoch [39/100] => Train Age Loss: 0.005019403, Train Race Loss: 0.954966688, Train Gender Loss: 0.323845200, Train Total Loss: 1.766334041
# Epoch [39/100] => Valid Age Loss: 0.008974250, Valid Race Loss: 1.030371887, Valid Gender Loss: 0.341715833, Valid Total Loss: 1.905222165
# Epoch [40/100] => Train Age Loss: 0.004684514, Train Race Loss: 0.955414704, Train Gender Loss: 0.323726895, Train Total Loss: 1.766217979
# Epoch [40/100] => Valid Age Loss: 0.009451242, Valid Race Loss: 1.049993898, Valid Gender Loss: 0.341581704, Valid Total Loss: 1.935475033
# Epoch [41/100] => Train Age Loss: 0.004728793, Train Race Loss: 0.950475597, Train Gender Loss: 0.324941677, Train Total Loss: 1.760112657
# Epoch [41/100] => Valid Age Loss: 0.009286748, Valid Race Loss: 1.028881546, Valid Gender Loss: 0.341667555, Valid Total Loss: 1.903563370
# Epoch [42/100] => Train Age Loss: 0.004545387, Train Race Loss: 0.949076412, Train Gender Loss: 0.322555621, Train Total Loss: 1.755261009
# Epoch [42/100] => Valid Age Loss: 0.008702110, Valid Race Loss: 1.043680756, Valid Gender Loss: 0.339730525, Valid Total Loss: 1.922655883
# Epoch [43/100] => Train Age Loss: 0.004271354, Train Race Loss: 0.948157892, Train Gender Loss: 0.323476171, Train Total Loss: 1.754255715
# Epoch [43/100] => Valid Age Loss: 0.008823859, Valid Race Loss: 1.037898798, Valid Gender Loss: 0.342672490, Valid Total Loss: 1.917168402
# Epoch [44/100] => Train Age Loss: 0.004267323, Train Race Loss: 0.945640641, Train Gender Loss: 0.322939803, Train Total Loss: 1.749935408
# Epoch [44/100] => Valid Age Loss: 0.009129951, Valid Race Loss: 1.032132631, Valid Gender Loss: 0.339733506, Valid Total Loss: 1.906192353
# Epoch [45/100] => Train Age Loss: 0.004367621, Train Race Loss: 0.948511245, Train Gender Loss: 0.324533615, Train Total Loss: 1.756035719
# Epoch [45/100] => Valid Age Loss: 0.008815785, Valid Race Loss: 1.032761193, Valid Gender Loss: 0.344092896, Valid Total Loss: 1.910866260
# Epoch [46/100] => Train Age Loss: 0.004387578, Train Race Loss: 0.946611187, Train Gender Loss: 0.323037573, Train Total Loss: 1.751729515
# Epoch [46/100] => Valid Age Loss: 0.009011570, Valid Race Loss: 1.033443644, Valid Gender Loss: 0.339605830, Valid Total Loss: 1.907794434
# Epoch [47/100] => Train Age Loss: 0.004228439, Train Race Loss: 0.945733302, Train Gender Loss: 0.323964821, Train Total Loss: 1.751021644
# Epoch [47/100] => Valid Age Loss: 0.009115533, Valid Race Loss: 1.035637647, Valid Gender Loss: 0.346789789, Valid Total Loss: 1.918477329
# Epoch [48/100] => Train Age Loss: 0.004373987, Train Race Loss: 0.949309576, Train Gender Loss: 0.324184320, Train Total Loss: 1.756896657
# Epoch [48/100] => Valid Age Loss: 0.009170250, Valid Race Loss: 1.026701420, Valid Gender Loss: 0.340464636, Valid Total Loss: 1.898857258
# Epoch [49/100] => Train Age Loss: 0.004198001, Train Race Loss: 0.944296374, Train Gender Loss: 0.323828380, Train Total Loss: 1.748668943
# Epoch [49/100] => Valid Age Loss: 0.009474501, Valid Race Loss: 1.029169243, Valid Gender Loss: 0.340091370, Valid Total Loss: 1.902794240
# Epoch [50/100] => Train Age Loss: 0.004281676, Train Race Loss: 0.945614750, Train Gender Loss: 0.323353737, Train Total Loss: 1.750339219
# Epoch [50/100] => Valid Age Loss: 0.009107723, Valid Race Loss: 1.037307800, Valid Gender Loss: 0.339404905, Valid Total Loss: 1.913582060
# Epoch [51/100] => Train Age Loss: 0.004262320, Train Race Loss: 0.945519741, Train Gender Loss: 0.323556356, Train Total Loss: 1.750360609
# Epoch [51/100] => Valid Age Loss: 0.008939046, Valid Race Loss: 1.032643731, Valid Gender Loss: 0.340989799, Valid Total Loss: 1.907833485
# Epoch [52/100] => Train Age Loss: 0.003875559, Train Race Loss: 0.942298580, Train Gender Loss: 0.322390682, Train Total Loss: 1.743589663
# Epoch [52/100] => Valid Age Loss: 0.008801659, Valid Race Loss: 1.033072773, Valid Gender Loss: 0.339031943, Valid Total Loss: 1.906244410
# Epoch [53/100] => Train Age Loss: 0.004100900, Train Race Loss: 0.944279524, Train Gender Loss: 0.322810810, Train Total Loss: 1.747431897
# Epoch [53/100] => Valid Age Loss: 0.008873385, Valid Race Loss: 1.029707310, Valid Gender Loss: 0.339726099, Valid Total Loss: 1.902033837
# Epoch [54/100] => Train Age Loss: 0.003898605, Train Race Loss: 0.941225690, Train Gender Loss: 0.322415019, Train Total Loss: 1.742050772
# Epoch [54/100] => Valid Age Loss: 0.009015168, Valid Race Loss: 1.032770590, Valid Gender Loss: 0.339046759, Valid Total Loss: 1.906232972
# Epoch [55/100] => Train Age Loss: 0.003792485, Train Race Loss: 0.941900986, Train Gender Loss: 0.323098982, Train Total Loss: 1.743535438
# Epoch [55/100] => Valid Age Loss: 0.009006787, Valid Race Loss: 1.028397735, Valid Gender Loss: 0.338263560, Valid Total Loss: 1.898873745
# Epoch [56/100] => Train Age Loss: 0.003817012, Train Race Loss: 0.942788323, Train Gender Loss: 0.322653018, Train Total Loss: 1.744469526
# Epoch [56/100] => Valid Age Loss: 0.009050719, Valid Race Loss: 1.042209223, Valid Gender Loss: 0.342563968, Valid Total Loss: 1.923979243
# Epoch [57/100] => Train Age Loss: 0.003928138, Train Race Loss: 0.943676526, Train Gender Loss: 0.322068667, Train Total Loss: 1.745439725
# Epoch [57/100] => Valid Age Loss: 0.009300300, Valid Race Loss: 1.029344194, Valid Gender Loss: 0.338548137, Valid Total Loss: 1.901165031
# Epoch [58/100] => Train Age Loss: 0.003891797, Train Race Loss: 0.941655189, Train Gender Loss: 0.322550274, Train Total Loss: 1.742816646
# Epoch [58/100] => Valid Age Loss: 0.009363467, Valid Race Loss: 1.028178761, Valid Gender Loss: 0.342658949, Valid Total Loss: 1.903654034
# Epoch [59/100] => Train Age Loss: 0.003860914, Train Race Loss: 0.941038885, Train Gender Loss: 0.322587468, Train Total Loss: 1.741867627
# Epoch [59/100] => Valid Age Loss: 0.008802046, Valid Race Loss: 1.022602497, Valid Gender Loss: 0.349099923, Valid Total Loss: 1.900607755
# Epoch [60/100] => Train Age Loss: 0.003672868, Train Race Loss: 0.941173440, Train Gender Loss: 0.323773364, Train Total Loss: 1.742879262
# Epoch [60/100] => Valid Age Loss: 0.008935350, Valid Race Loss: 1.025599691, Valid Gender Loss: 0.338495033, Valid Total Loss: 1.894765262
# Epoch [61/100] => Train Age Loss: 0.003539882, Train Race Loss: 0.937346395, Train Gender Loss: 0.323190506, Train Total Loss: 1.736289866
# Epoch [61/100] => Valid Age Loss: 0.008797133, Valid Race Loss: 1.031097678, Valid Gender Loss: 0.341692864, Valid Total Loss: 1.905933633
# Epoch [62/100] => Train Age Loss: 0.003577973, Train Race Loss: 0.939053134, Train Gender Loss: 0.321714051, Train Total Loss: 1.737449696
# Epoch [62/100] => Valid Age Loss: 0.008674858, Valid Race Loss: 1.028674264, Valid Gender Loss: 0.339342932, Valid Total Loss: 1.899704041
# Epoch [63/100] => Train Age Loss: 0.003640216, Train Race Loss: 0.939584250, Train Gender Loss: 0.322169063, Train Total Loss: 1.738825870
# Epoch [63/100] => Valid Age Loss: 0.008589343, Valid Race Loss: 1.027106802, Valid Gender Loss: 0.340511245, Valid Total Loss: 1.898350133
# Epoch [64/100] => Train Age Loss: 0.003575820, Train Race Loss: 0.940908968, Train Gender Loss: 0.322711443, Train Total Loss: 1.741226538
# Epoch [64/100] => Valid Age Loss: 0.008241068, Valid Race Loss: 1.028131435, Valid Gender Loss: 0.336029484, Valid Total Loss: 1.894708776
# Epoch [65/100] => Train Age Loss: 0.003515147, Train Race Loss: 0.940031820, Train Gender Loss: 0.322584610, Train Total Loss: 1.739662633
# Epoch [65/100] => Valid Age Loss: 0.008617342, Valid Race Loss: 1.031147006, Valid Gender Loss: 0.339712615, Valid Total Loss: 1.903667796
# Epoch [66/100] => Train Age Loss: 0.003381258, Train Race Loss: 0.938818717, Train Gender Loss: 0.323840190, Train Total Loss: 1.738830777
# Epoch [66/100] => Valid Age Loss: 0.008847629, Valid Race Loss: 1.026836579, Valid Gender Loss: 0.347277147, Valid Total Loss: 1.905227270
# Epoch [67/100] => Train Age Loss: 0.003670845, Train Race Loss: 0.943340114, Train Gender Loss: 0.322785138, Train Total Loss: 1.745136993
# Epoch [67/100] => Valid Age Loss: 0.008899311, Valid Race Loss: 1.033226559, Valid Gender Loss: 0.338817952, Valid Total Loss: 1.906456415
# Epoch [68/100] => Train Age Loss: 0.003683486, Train Race Loss: 0.941070798, Train Gender Loss: 0.322191141, Train Total Loss: 1.741164301
# Epoch [68/100] => Valid Age Loss: 0.008791317, Valid Race Loss: 1.028150796, Valid Gender Loss: 0.344091470, Valid Total Loss: 1.903900289
# Epoch [69/100] => Train Age Loss: 0.003469929, Train Race Loss: 0.936442401, Train Gender Loss: 0.322028792, Train Total Loss: 1.733632250
# Epoch [69/100] => Valid Age Loss: 0.009228655, Valid Race Loss: 1.029595623, Valid Gender Loss: 0.338018005, Valid Total Loss: 1.900868753
# Epoch [70/100] => Train Age Loss: 0.003543163, Train Race Loss: 0.937290417, Train Gender Loss: 0.322382432, Train Total Loss: 1.735404384
# Epoch [70/100] => Valid Age Loss: 0.008574255, Valid Race Loss: 1.024551800, Valid Gender Loss: 0.341486661, Valid Total Loss: 1.895462874
# Epoch [71/100] => Train Age Loss: 0.003253317, Train Race Loss: 0.935252347, Train Gender Loss: 0.323030454, Train Total Loss: 1.732415608
# Epoch [71/100] => Valid Age Loss: 0.009093606, Valid Race Loss: 1.029544741, Valid Gender Loss: 0.343556036, Valid Total Loss: 1.906060350
# Epoch [72/100] => Train Age Loss: 0.003638988, Train Race Loss: 0.942470081, Train Gender Loss: 0.323370714, Train Total Loss: 1.744353812
# Epoch [72/100] => Valid Age Loss: 0.008449514, Valid Race Loss: 1.028240770, Valid Gender Loss: 0.342093432, Valid Total Loss: 1.901353623
# Epoch [73/100] => Train Age Loss: 0.003512033, Train Race Loss: 0.938964555, Train Gender Loss: 0.323295343, Train Total Loss: 1.738766243
# Epoch [73/100] => Valid Age Loss: 0.009047558, Valid Race Loss: 1.032728217, Valid Gender Loss: 0.343932674, Valid Total Loss: 1.911120119
# Epoch [74/100] => Train Age Loss: 0.003720890, Train Race Loss: 0.940681320, Train Gender Loss: 0.322378588, Train Total Loss: 1.740842346
# Epoch [74/100] => Valid Age Loss: 0.008631989, Valid Race Loss: 1.030494062, Valid Gender Loss: 0.340604696, Valid Total Loss: 1.903609766
# Epoch [75/100] => Train Age Loss: 0.003514614, Train Race Loss: 0.938078482, Train Gender Loss: 0.322083004, Train Total Loss: 1.736229948
# Epoch [75/100] => Valid Age Loss: 0.008831192, Valid Race Loss: 1.028463937, Valid Gender Loss: 0.344132672, Valid Total Loss: 1.904490961
# Epoch [76/100] => Train Age Loss: 0.003341621, Train Race Loss: 0.936537367, Train Gender Loss: 0.321314769, Train Total Loss: 1.732804063
# Epoch [76/100] => Valid Age Loss: 0.008330469, Valid Race Loss: 1.029211502, Valid Gender Loss: 0.338557786, Valid Total Loss: 1.899035972
# Epoch [77/100] => Train Age Loss: 0.003095567, Train Race Loss: 0.934845366, Train Gender Loss: 0.321836936, Train Total Loss: 1.730296119
# Epoch [77/100] => Valid Age Loss: 0.009152864, Valid Race Loss: 1.022872056, Valid Gender Loss: 0.343480834, Valid Total Loss: 1.896094651
# Epoch [78/100] => Train Age Loss: 0.003383149, Train Race Loss: 0.935522474, Train Gender Loss: 0.321323690, Train Total Loss: 1.731373702
# Epoch [78/100] => Valid Age Loss: 0.008670123, Valid Race Loss: 1.025585338, Valid Gender Loss: 0.339519395, Valid Total Loss: 1.895237653
# Epoch [79/100] => Train Age Loss: 0.003031641, Train Race Loss: 0.934529355, Train Gender Loss: 0.320411131, Train Total Loss: 1.728268451
# Epoch [79/100] => Valid Age Loss: 0.008429327, Valid Race Loss: 1.021819124, Valid Gender Loss: 0.344647284, Valid Total Loss: 1.894234626
# Epoch [80/100] => Train Age Loss: 0.003311396, Train Race Loss: 0.936447532, Train Gender Loss: 0.322858631, Train Total Loss: 1.734152725
# Epoch [80/100] => Valid Age Loss: 0.008956080, Valid Race Loss: 1.031201044, Valid Gender Loss: 0.343493400, Valid Total Loss: 1.908207124
# Epoch [81/100] => Train Age Loss: 0.003561290, Train Race Loss: 0.937057365, Train Gender Loss: 0.321626818, Train Total Loss: 1.734335442
# Epoch [81/100] => Valid Age Loss: 0.009189580, Valid Race Loss: 1.026299477, Valid Gender Loss: 0.336764235, Valid Total Loss: 1.894592618
# Epoch [82/100] => Train Age Loss: 0.003524809, Train Race Loss: 0.938497735, Train Gender Loss: 0.322400721, Train Total Loss: 1.737196943
# Epoch [82/100] => Valid Age Loss: 0.008826018, Valid Race Loss: 1.026267677, Valid Gender Loss: 0.337855358, Valid Total Loss: 1.894908922
# Epoch [83/100] => Train Age Loss: 0.003428418, Train Race Loss: 0.936041464, Train Gender Loss: 0.324119453, Train Total Loss: 1.735038489
# Epoch [83/100] => Valid Age Loss: 0.008567005, Valid Race Loss: 1.023556451, Valid Gender Loss: 0.348900048, Valid Total Loss: 1.901368733
# Epoch [84/100] => Train Age Loss: 0.003289257, Train Race Loss: 0.936968272, Train Gender Loss: 0.322800024, Train Total Loss: 1.734830946
# Epoch [84/100] => Valid Age Loss: 0.008826282, Valid Race Loss: 1.020147970, Valid Gender Loss: 0.339359778, Valid Total Loss: 1.887234295
# Epoch [85/100] => Train Age Loss: 0.003214800, Train Race Loss: 0.935478431, Train Gender Loss: 0.322562137, Train Total Loss: 1.732209387
# Epoch [85/100] => Valid Age Loss: 0.009262744, Valid Race Loss: 1.029296960, Valid Gender Loss: 0.340726193, Valid Total Loss: 1.903197118
# Epoch [86/100] => Train Age Loss: 0.003435791, Train Race Loss: 0.938954814, Train Gender Loss: 0.323123208, Train Total Loss: 1.738427014
# Epoch [86/100] => Valid Age Loss: 0.008401186, Valid Race Loss: 1.021406849, Valid Gender Loss: 0.338126404, Valid Total Loss: 1.887039059
# Epoch [87/100] => Train Age Loss: 0.003185751, Train Race Loss: 0.934292405, Train Gender Loss: 0.321015576, Train Total Loss: 1.728825684
# Epoch [87/100] => Valid Age Loss: 0.008574639, Valid Race Loss: 1.021836375, Valid Gender Loss: 0.338580229, Valid Total Loss: 1.888484083
# Epoch [88/100] => Train Age Loss: 0.003132520, Train Race Loss: 0.936354880, Train Gender Loss: 0.321930176, Train Total Loss: 1.732727529
# Epoch [88/100] => Valid Age Loss: 0.009223689, Valid Race Loss: 1.025772224, Valid Gender Loss: 0.337143735, Valid Total Loss: 1.894249451
# Epoch [89/100] => Train Age Loss: 0.003390038, Train Race Loss: 0.936329038, Train Gender Loss: 0.321637775, Train Total Loss: 1.732911416
# Epoch [89/100] => Valid Age Loss: 0.009263797, Valid Race Loss: 1.031435329, Valid Gender Loss: 0.338318219, Valid Total Loss: 1.903998808
# Epoch [90/100] => Train Age Loss: 0.003205938, Train Race Loss: 0.935170145, Train Gender Loss: 0.321250749, Train Total Loss: 1.730417851
# Epoch [90/100] => Valid Age Loss: 0.008367585, Valid Race Loss: 1.022112510, Valid Gender Loss: 0.342163748, Valid Total Loss: 1.892067678
# Epoch [91/100] => Train Age Loss: 0.002943668, Train Race Loss: 0.931385438, Train Gender Loss: 0.321631546, Train Total Loss: 1.724597033
# Epoch [91/100] => Valid Age Loss: 0.008360621, Valid Race Loss: 1.023978936, Valid Gender Loss: 0.339361753, Valid Total Loss: 1.892051407
# Epoch [92/100] => Train Age Loss: 0.003226695, Train Race Loss: 0.938640391, Train Gender Loss: 0.322147124, Train Total Loss: 1.736561096
# Epoch [92/100] => Valid Age Loss: 0.008611326, Valid Race Loss: 1.032599388, Valid Gender Loss: 0.338346132, Valid Total Loss: 1.904467866
# Epoch [93/100] => Train Age Loss: 0.002916380, Train Race Loss: 0.933738005, Train Gender Loss: 0.321284582, Train Total Loss: 1.727724355
# Epoch [93/100] => Valid Age Loss: 0.008564052, Valid Race Loss: 1.017923829, Valid Gender Loss: 0.339675287, Valid Total Loss: 1.883689123
# Epoch [94/100] => Train Age Loss: 0.002825346, Train Race Loss: 0.933131304, Train Gender Loss: 0.320737669, Train Total Loss: 1.726085317
# Epoch [94/100] => Valid Age Loss: 0.008238516, Valid Race Loss: 1.025806782, Valid Gender Loss: 0.340009388, Valid Total Loss: 1.895196594
# Epoch [95/100] => Train Age Loss: 0.003004209, Train Race Loss: 0.934243807, Train Gender Loss: 0.322127015, Train Total Loss: 1.729501145
# Epoch [95/100] => Valid Age Loss: 0.009240995, Valid Race Loss: 1.026210996, Valid Gender Loss: 0.338594701, Valid Total Loss: 1.896393173
# Epoch [96/100] => Train Age Loss: 0.002857790, Train Race Loss: 0.933439136, Train Gender Loss: 0.320773709, Train Total Loss: 1.726647987
# Epoch [96/100] => Valid Age Loss: 0.008468273, Valid Race Loss: 1.029074560, Valid Gender Loss: 0.341784889, Valid Total Loss: 1.902333269
# Epoch [97/100] => Train Age Loss: 0.003126652, Train Race Loss: 0.934047140, Train Gender Loss: 0.323684775, Train Total Loss: 1.731008778
# Epoch [97/100] => Valid Age Loss: 0.008625437, Valid Race Loss: 1.025760727, Valid Gender Loss: 0.340409633, Valid Total Loss: 1.896301598
# Epoch [98/100] => Train Age Loss: 0.002978789, Train Race Loss: 0.933951603, Train Gender Loss: 0.321557336, Train Total Loss: 1.728442314
# Epoch [98/100] => Valid Age Loss: 0.008564190, Valid Race Loss: 1.021450913, Valid Gender Loss: 0.340073183, Valid Total Loss: 1.889377922
# Epoch [99/100] => Train Age Loss: 0.002963153, Train Race Loss: 0.934022614, Train Gender Loss: 0.321245623, Train Total Loss: 1.728205850
# Epoch [99/100] => Valid Age Loss: 0.008745061, Valid Race Loss: 1.023584999, Valid Gender Loss: 0.342801564, Valid Total Loss: 1.895669187
# Epoch [100/100] => Train Age Loss: 0.002996358, Train Race Loss: 0.931713400, Train Gender Loss: 0.321381358, Train Total Loss: 1.724944179
# Epoch [100/100] => Valid Age Loss: 0.008639897, Valid Race Loss: 1.016425271, Valid Gender Loss: 0.340758571, Valid Total Loss: 1.882676268
# Training took 11711.47 seconds

# %%
# Plotting the loss curves

plt.figure(figsize=(15, 10))

# Age Loss curve
plt.subplot(2, 2, 1)
plt.plot(train_loss_age, label='Train Age Loss', color='blue')
plt.plot(valid_loss_age, label='Valid Age Loss', color='cyan', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Age Loss')
plt.legend()
plt.grid(True)

# Race Loss curve
plt.subplot(2, 2, 2)
plt.plot(train_loss_race, label='Train Race Loss', color='green')
plt.plot(valid_loss_race, label='Valid Race Loss', color='lime', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Race Loss')
plt.legend()
plt.grid(True)

# Gender Loss curve
plt.subplot(2, 2, 3)
plt.plot(train_loss_gender, label='Train Gender Loss', color='red')
plt.plot(valid_loss_gender, label='Valid Gender Loss', color='pink', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Gender Loss')
plt.legend()
plt.grid(True)

# Total Loss curve
plt.subplot(2, 2, 4)
plt.plot(train_total_loss, label='Train Total Loss', color='black')
plt.plot(valid_total_loss, label='Valid Total Loss', color='gray', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Total Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report,mean_absolute_error, mean_squared_error

# Lists to store true labels and predictions
true_ages, pred_ages = [], []
true_races, pred_races = [], []
true_genders, pred_genders = [], []

# Set the model to evaluation mode
model.eval()

# Disable gradient computation
with torch.no_grad():
    for images, ages, races, genders in valid_loader:  # Assuming you have a validation loader called 'val_loader'
        images = images.float().to(device)

        # Get predictions
        age_preds, race_preds, gender_preds = model(images)

        # Convert predictions to class labels
        _, predicted_races = torch.max(race_preds, 1)
        _, predicted_genders = torch.max(gender_preds, 1)

        # Append true labels and predicted labels
        true_ages.extend(ages.cpu().numpy())
        pred_ages.extend(age_preds.squeeze(1).cpu().numpy())

        true_races.extend(torch.argmax(races, dim=1).cpu().numpy())
        pred_races.extend(predicted_races.cpu().numpy())

        true_genders.extend(torch.argmax(genders, dim=1).cpu().numpy())
        pred_genders.extend(predicted_genders.cpu().numpy())

# Generate classification reports
print("Classification report for Age:")
# For regression task like Age, you might want to compute other metrics like MAE or MSE instead of classification report
# For demonstration, I'm just printing the first 10 true and predicted ages
print("True Ages:", true_ages[:10])
print("Predicted Ages:", pred_ages[:10])

# print("\nClassification report for Ages:")
# print(classification_report(true_ages, pred_ages))

# Report for Age:
print("Report for Age:")
mae = mean_absolute_error(true_ages, pred_ages)
mse = mean_squared_error(true_ages, pred_ages)
print(f"Mean Absolute Error for Age: {mae:.4f}")
print(f"Mean Squared Error for Age: {mse:.4f}")

print("\nClassification report for Race:")
print(classification_report(true_races, pred_races))

print("\nClassification report for Gender:")
print(classification_report(true_genders, pred_genders))
# Out:
# Classification report for Age:
# True Ages: [0.6666666666666666, 0.5217391304347826, 0.4927536231884058, 0.43478260869565216, 0.3333333333333333, 0.43478260869565216, 0.7246376811594203, 0.4492753623188406, 0.4927536231884058, 0.34782608695652173]
# Predicted Ages: [0.75744855, 0.503064, 0.545327, 0.7053415, 0.34716862, 0.42547262, 0.7561442, 0.5466166, 0.43001416, 0.42162606]
# Report for Age:
# Mean Absolute Error for Age: 0.0667
# Mean Squared Error for Age: 0.0086
#
# Classification report for Race:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90      2360
#            1       0.93      0.93      0.93      1644
#            2       0.92      0.91      0.91       865
#            3       0.85      0.91      0.88      1287
#            4       0.70      0.57      0.63       523
#
#     accuracy                           0.89      6679
#    macro avg       0.86      0.85      0.85      6679
# weighted avg       0.89      0.89      0.89      6679
#
#
# Classification report for Gender:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3632
#            1       0.97      0.97      0.97      3047
#
#     accuracy                           0.97      6679
#    macro avg       0.97      0.97      0.97      6679
# weighted avg       0.97      0.97      0.97      6679

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_predictions(model, loader, num_images=5):
    model.eval()
    image_count = 0
    fig, axs = plt.subplots(num_images, figsize=(10, 5 * num_images))

    with torch.no_grad():
          for images, ages, races, genders in loader:
            if image_count >= num_images:
#         for idx, (images, ages, races, genders) in enumerate(loader):
#             if idx == num_images:
                break

            images = images.float().to(device)
            age_preds, race_preds, gender_preds = model(images)

            _, predicted_races = torch.max(race_preds, 1)
            _, predicted_genders = torch.max(gender_preds, 1)

            for i in range(images.size(0)):
                if image_count >= num_images:
                    break
            # Convert the predictions back to the label names
            pred_age = int(age_preds[i].squeeze().item() * max_age)
            true_age = int(ages[i].item() * max_age)

            # Assuming you have a reverse dictionary to map from label ID back to race name
#             pred_race = REVERSE_RACE_ID_MAP[predicted_races.item()]  
#             true_race = REVERSE_RACE_ID_MAP[torch.argmax(races, dim=1).item()]

            pred_race = ID_RACE_MAP[predicted_races[i].item()]
            true_race = ID_RACE_MAP[torch.argmax(races[i], dim=0).item()]


#             pred_gender = "Male" if predicted_genders.item() == 1 else "Female"
#             true_gender = "Male" if torch.argmax(genders, dim=1).item() == 1 else "Female"
            pred_gender = "Female" if predicted_genders[i].item() == 1 else "Male"
            true_gender = "Female" if torch.argmax(genders[i], dim=0).item() == 1 else "Male"
                
            # Plotting the image with predictions and true labels
#             axs[idx].imshow(np.transpose(images[0].cpu().numpy(), (1, 2, 0)))
#             axs[idx].axis('off')
#             axs[idx].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
            axs[image_count].imshow(np.transpose(images[i].cpu().numpy(), (1, 2, 0)))
            axs[image_count].axis('off')
            axs[image_count].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
                
            image_count += 1

    plt.tight_layout()
    plt.show()

# Visualize the predictions on the validation dataset
visualize_predictions(model, valid_loader)

# %%
# Out:
# Epoch [1/100] => Age Loss: 0.017128856, Race Loss: 1.369204625, Gender Loss: 0.530549374, Total Loss: 2.618614018
# Epoch [2/100] => Age Loss: 0.012402151, Race Loss: 1.166383097, Gender Loss: 0.375411998, Total Loss: 2.149790942
# Epoch [3/100] => Age Loss: 0.011223462, Race Loss: 1.088272260, Gender Loss: 0.354720407, Total Loss: 2.009575710
# Epoch [4/100] => Age Loss: 0.010555888, Race Loss: 1.067243684, Gender Loss: 0.350553247, Total Loss: 1.972530548
# Epoch [5/100] => Age Loss: 0.009783273, Race Loss: 1.057696561, Gender Loss: 0.342765353, Total Loss: 1.948876742
# Epoch [6/100] => Age Loss: 0.009550692, Race Loss: 1.048065992, Gender Loss: 0.340306167, Total Loss: 1.931506549
# Epoch [7/100] => Age Loss: 0.009247503, Race Loss: 1.040514796, Gender Loss: 0.339730959, Total Loss: 1.918998167
# Epoch [8/100] => Age Loss: 0.008626358, Race Loss: 1.035880858, Gender Loss: 0.337303656, Total Loss: 1.908377651
# Epoch [9/100] => Age Loss: 0.008193599, Race Loss: 1.028433193, Gender Loss: 0.335414222, Total Loss: 1.894451204
# Epoch [10/100] => Age Loss: 0.008078875, Race Loss: 1.029174486, Gender Loss: 0.333614757, Total Loss: 1.893534233
# Epoch [11/100] => Age Loss: 0.007381994, Race Loss: 1.022756415, Gender Loss: 0.332390425, Total Loss: 1.881289038
# Epoch [12/100] => Age Loss: 0.007165050, Race Loss: 1.019872556, Gender Loss: 0.331420283, Total Loss: 1.875559218
# Epoch [13/100] => Age Loss: 0.006892500, Race Loss: 1.014260981, Gender Loss: 0.330538523, Total Loss: 1.865714996
# Epoch [14/100] => Age Loss: 0.006628206, Race Loss: 1.011630539, Gender Loss: 0.329932856, Total Loss: 1.860635082
# Epoch [15/100] => Age Loss: 0.006372226, Race Loss: 1.006518754, Gender Loss: 0.330237236, Total Loss: 1.852759817
# Epoch [16/100] => Age Loss: 0.006416254, Race Loss: 1.009622541, Gender Loss: 0.328486830, Total Loss: 1.855753147
# Epoch [17/100] => Age Loss: 0.006370366, Race Loss: 0.997070548, Gender Loss: 0.329384501, Total Loss: 1.837731054
# Epoch [18/100] => Age Loss: 0.006407363, Race Loss: 0.992445090, Gender Loss: 0.328359275, Total Loss: 1.829841642
# Epoch [19/100] => Age Loss: 0.006217831, Race Loss: 0.992961478, Gender Loss: 0.327926595, Total Loss: 1.829804477
# Epoch [20/100] => Age Loss: 0.006442794, Race Loss: 0.987358694, Gender Loss: 0.329632358, Total Loss: 1.823555990
# Epoch [21/100] => Age Loss: 0.006137850, Race Loss: 0.985183548, Gender Loss: 0.327991446, Total Loss: 1.818042479
# Epoch [22/100] => Age Loss: 0.005830788, Race Loss: 0.978142057, Gender Loss: 0.327913916, Total Loss: 1.806788573
# Epoch [23/100] => Age Loss: 0.005771642, Race Loss: 0.972843803, Gender Loss: 0.325752787, Total Loss: 1.796561782
# Epoch [24/100] => Age Loss: 0.005724727, Race Loss: 0.971074579, Gender Loss: 0.326326300, Total Loss: 1.794387634
# Epoch [25/100] => Age Loss: 0.005340304, Race Loss: 0.967903418, Gender Loss: 0.325647736, Total Loss: 1.788183471
# Epoch [26/100] => Age Loss: 0.005284742, Race Loss: 0.970785314, Gender Loss: 0.324856900, Total Loss: 1.791604359
# Epoch [27/100] => Age Loss: 0.005484997, Race Loss: 0.966764705, Gender Loss: 0.325208412, Total Loss: 1.786325459
# Epoch [28/100] => Age Loss: 0.005081627, Race Loss: 0.964492460, Gender Loss: 0.324431582, Total Loss: 1.781333527
# Epoch [29/100] => Age Loss: 0.005032210, Race Loss: 0.960928496, Gender Loss: 0.324306228, Total Loss: 1.775763391
# Epoch [30/100] => Age Loss: 0.004929880, Race Loss: 0.962340905, Gender Loss: 0.325569578, Total Loss: 1.778940700
# Epoch [31/100] => Age Loss: 0.004923231, Race Loss: 0.958363040, Gender Loss: 0.324038065, Total Loss: 1.771429090
# Epoch [32/100] => Age Loss: 0.004539667, Race Loss: 0.953408427, Gender Loss: 0.324978847, Total Loss: 1.764170827
# Epoch [33/100] => Age Loss: 0.004639826, Race Loss: 0.955636775, Gender Loss: 0.325708511, Total Loss: 1.768443327
# Epoch [34/100] => Age Loss: 0.004940467, Race Loss: 0.955953854, Gender Loss: 0.324334590, Total Loss: 1.768146308
# Epoch [35/100] => Age Loss: 0.004609890, Race Loss: 0.953986126, Gender Loss: 0.323479932, Total Loss: 1.763678903
# Epoch [36/100] => Age Loss: 0.004463454, Race Loss: 0.952577641, Gender Loss: 0.323524469, Total Loss: 1.761317842
# Epoch [37/100] => Age Loss: 0.004433480, Race Loss: 0.954625822, Gender Loss: 0.324314223, Total Loss: 1.765119917
# Epoch [38/100] => Age Loss: 0.004662184, Race Loss: 0.953795568, Gender Loss: 0.324564638, Total Loss: 1.764582354
# Epoch [39/100] => Age Loss: 0.004495434, Race Loss: 0.951754911, Gender Loss: 0.323854825, Total Loss: 1.760478056
# Epoch [40/100] => Age Loss: 0.004154044, Race Loss: 0.949623952, Gender Loss: 0.323423640, Total Loss: 1.756167659
# Epoch [41/100] => Age Loss: 0.004333518, Race Loss: 0.952251597, Gender Loss: 0.323057264, Total Loss: 1.760101696
# Epoch [42/100] => Age Loss: 0.004311990, Race Loss: 0.952704667, Gender Loss: 0.325325229, Total Loss: 1.763006209
# Epoch [43/100] => Age Loss: 0.004252600, Race Loss: 0.947161817, Gender Loss: 0.323597725, Total Loss: 1.752845650
# Epoch [44/100] => Age Loss: 0.003809833, Race Loss: 0.943524430, Gender Loss: 0.322673865, Total Loss: 1.745580171
# Epoch [45/100] => Age Loss: 0.003965568, Race Loss: 0.947155908, Gender Loss: 0.324053924, Total Loss: 1.752718919
# Epoch [46/100] => Age Loss: 0.003954198, Race Loss: 0.947639041, Gender Loss: 0.323788994, Total Loss: 1.753155946
# Epoch [47/100] => Age Loss: 0.003993665, Race Loss: 0.946461798, Gender Loss: 0.324355132, Total Loss: 1.752035162
# Epoch [48/100] => Age Loss: 0.003921939, Race Loss: 0.946722358, Gender Loss: 0.323818776, Total Loss: 1.751746192
# Epoch [49/100] => Age Loss: 0.003971191, Race Loss: 0.947760768, Gender Loss: 0.325796839, Total Loss: 1.755380374
# Epoch [50/100] => Age Loss: 0.003992069, Race Loss: 0.946308453, Gender Loss: 0.323351208, Total Loss: 1.750798026
# Epoch [51/100] => Age Loss: 0.003876810, Race Loss: 0.943916818, Gender Loss: 0.323164498, Total Loss: 1.746793345
# Epoch [52/100] => Age Loss: 0.004071551, Race Loss: 0.946180319, Gender Loss: 0.322336877, Total Loss: 1.749750452
# Epoch [53/100] => Age Loss: 0.003722076, Race Loss: 0.941896420, Gender Loss: 0.322061830, Total Loss: 1.742350608
# Epoch [54/100] => Age Loss: 0.003480361, Race Loss: 0.940385861, Gender Loss: 0.322920250, Total Loss: 1.740459765
# Epoch [55/100] => Age Loss: 0.003473937, Race Loss: 0.940476329, Gender Loss: 0.322419524, Total Loss: 1.740081891
# Epoch [56/100] => Age Loss: 0.003617127, Race Loss: 0.945174389, Gender Loss: 0.321974643, Total Loss: 1.746970481
# Epoch [57/100] => Age Loss: 0.003738743, Race Loss: 0.943504974, Gender Loss: 0.322152320, Total Loss: 1.744887263
# Epoch [58/100] => Age Loss: 0.003627854, Race Loss: 0.941380630, Gender Loss: 0.322853740, Total Loss: 1.742180393
# Epoch [59/100] => Age Loss: 0.003441315, Race Loss: 0.939628325, Gender Loss: 0.322969088, Total Loss: 1.739294199
# Epoch [60/100] => Age Loss: 0.003359730, Race Loss: 0.941289474, Gender Loss: 0.322084562, Total Loss: 1.740738236
# Epoch [61/100] => Age Loss: 0.003377493, Race Loss: 0.941433036, Gender Loss: 0.322045618, Total Loss: 1.740950159
# Epoch [62/100] => Age Loss: 0.003386028, Race Loss: 0.940142198, Gender Loss: 0.322496945, Total Loss: 1.739482302
# Epoch [63/100] => Age Loss: 0.003364140, Race Loss: 0.939694145, Gender Loss: 0.322576789, Total Loss: 1.738846281
# Epoch [64/100] => Age Loss: 0.003538166, Race Loss: 0.942136289, Gender Loss: 0.322579854, Total Loss: 1.742860624
# Epoch [65/100] => Age Loss: 0.003401356, Race Loss: 0.940780828, Gender Loss: 0.322592388, Total Loss: 1.740566340
# Epoch [66/100] => Age Loss: 0.003378598, Race Loss: 0.939210963, Gender Loss: 0.322685893, Total Loss: 1.738259543
# Epoch [67/100] => Age Loss: 0.003247153, Race Loss: 0.938644569, Gender Loss: 0.321906455, Total Loss: 1.736367610
# Epoch [68/100] => Age Loss: 0.003169854, Race Loss: 0.938896318, Gender Loss: 0.322123500, Total Loss: 1.736807688
# Epoch [69/100] => Age Loss: 0.003097164, Race Loss: 0.938057458, Gender Loss: 0.322079452, Total Loss: 1.735359965
# Epoch [70/100] => Age Loss: 0.003463547, Race Loss: 0.938461624, Gender Loss: 0.321710513, Total Loss: 1.736330040
# Epoch [71/100] => Age Loss: 0.003219769, Race Loss: 0.938250640, Gender Loss: 0.321443504, Total Loss: 1.735259006
# Epoch [72/100] => Age Loss: 0.003207294, Race Loss: 0.935833316, Gender Loss: 0.322143308, Total Loss: 1.732307869
# Epoch [73/100] => Age Loss: 0.003327361, Race Loss: 0.938431942, Gender Loss: 0.322101715, Total Loss: 1.736404354
# Epoch [74/100] => Age Loss: 0.002958360, Race Loss: 0.937117274, Gender Loss: 0.322214317, Total Loss: 1.733806949
# Epoch [75/100] => Age Loss: 0.003052337, Race Loss: 0.936133955, Gender Loss: 0.322004166, Total Loss: 1.732309764
# Epoch [76/100] => Age Loss: 0.003159858, Race Loss: 0.936525302, Gender Loss: 0.322543897, Total Loss: 1.733651573
# Epoch [77/100] => Age Loss: 0.003553003, Race Loss: 0.943049433, Gender Loss: 0.323239558, Total Loss: 1.744919711
# Epoch [78/100] => Age Loss: 0.003194598, Race Loss: 0.936542324, Gender Loss: 0.322908405, Total Loss: 1.734111086
# Epoch [79/100] => Age Loss: 0.003443807, Race Loss: 0.940221246, Gender Loss: 0.322028693, Total Loss: 1.739248181
# Epoch [80/100] => Age Loss: 0.003048487, Race Loss: 0.935044736, Gender Loss: 0.321483561, Total Loss: 1.730147639
# Epoch [81/100] => Age Loss: 0.002713225, Race Loss: 0.932824600, Gender Loss: 0.320766291, Total Loss: 1.725429640
# Epoch [82/100] => Age Loss: 0.002894063, Race Loss: 0.934713456, Gender Loss: 0.321219082, Total Loss: 1.729077391
# Epoch [83/100] => Age Loss: 0.002936439, Race Loss: 0.936800376, Gender Loss: 0.321531132, Total Loss: 1.732604567
# Epoch [84/100] => Age Loss: 0.002885932, Race Loss: 0.933973367, Gender Loss: 0.322799436, Total Loss: 1.729531349
# Epoch [85/100] => Age Loss: 0.002945202, Race Loss: 0.936324454, Gender Loss: 0.321204516, Total Loss: 1.731581601
# Epoch [86/100] => Age Loss: 0.002679496, Race Loss: 0.932385118, Gender Loss: 0.321384403, Total Loss: 1.725321068
# Epoch [87/100] => Age Loss: 0.002486063, Race Loss: 0.932809276, Gender Loss: 0.322215966, Total Loss: 1.726402009
# Epoch [88/100] => Age Loss: 0.002935821, Race Loss: 0.935570361, Gender Loss: 0.322220810, Total Loss: 1.731447991
# Epoch [89/100] => Age Loss: 0.002801462, Race Loss: 0.932313248, Gender Loss: 0.322728380, Total Loss: 1.726801170
# Epoch [90/100] => Age Loss: 0.002909421, Race Loss: 0.934397635, Gender Loss: 0.321516107, Total Loss: 1.728931402
# Epoch [91/100] => Age Loss: 0.002807547, Race Loss: 0.935434197, Gender Loss: 0.321752996, Total Loss: 1.730519381
# Epoch [92/100] => Age Loss: 0.002967368, Race Loss: 0.937607395, Gender Loss: 0.322467625, Total Loss: 1.734813454
# Epoch [93/100] => Age Loss: 0.003113267, Race Loss: 0.936541687, Gender Loss: 0.322067930, Total Loss: 1.733107004
# Epoch [94/100] => Age Loss: 0.002956083, Race Loss: 0.935093999, Gender Loss: 0.321707922, Total Loss: 1.730261084
# Epoch [95/100] => Age Loss: 0.002882477, Race Loss: 0.934912848, Gender Loss: 0.322380456, Total Loss: 1.730514679
# Epoch [96/100] => Age Loss: 0.002838999, Race Loss: 0.934526094, Gender Loss: 0.321496422, Total Loss: 1.728963562
# Epoch [97/100] => Age Loss: 0.002712445, Race Loss: 0.933682201, Gender Loss: 0.320293078, Total Loss: 1.726241268
# Epoch [98/100] => Age Loss: 0.002478262, Race Loss: 0.931990135, Gender Loss: 0.321938177, Total Loss: 1.724879908
# Epoch [99/100] => Age Loss: 0.002496444, Race Loss: 0.930712991, Gender Loss: 0.320963507, Total Loss: 1.722025883
# Epoch [100/100] => Age Loss: 0.002521850, Race Loss: 0.933534420, Gender Loss: 0.320599863, Total Loss: 1.725945188
# Training took 8642.39 seconds

# %%
# Plotting the loss curves

plt.figure(figsize=(15, 10))

# Age Loss curve
plt.subplot(2, 2, 1)
plt.plot(train_loss_age, label='Train Age Loss', color='blue')
plt.plot(valid_loss_age, label='Valid Age Loss', color='cyan', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Age Loss')
plt.legend()
plt.grid(True)

# Race Loss curve
plt.subplot(2, 2, 2)
plt.plot(train_loss_race, label='Train Race Loss', color='green')
plt.plot(valid_loss_race, label='Valid Race Loss', color='lime', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Race Loss')
plt.legend()
plt.grid(True)

# Gender Loss curve
plt.subplot(2, 2, 3)
plt.plot(train_loss_gender, label='Train Gender Loss', color='red')
plt.plot(valid_loss_gender, label='Valid Gender Loss', color='pink', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Gender Loss')
plt.legend()
plt.grid(True)

# Total Loss curve
plt.subplot(2, 2, 4)
plt.plot(train_total_loss, label='Train Total Loss', color='black')
plt.plot(valid_total_loss, label='Valid Total Loss', color='gray', linestyle='dashed')
plt.xlabel('Epochs')
plt.ylabel('Total Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model_directory = "/kaggle/working/Multitask_MobileNet_v3/"
os.makedirs(model_directory, exist_ok = True)

model_path = model_directory+"model_weights.pt"
torch.save(model, model_path)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_predictions(model, loader, num_images=5):
    model.eval()
    image_count = 0
    fig, axs = plt.subplots(num_images, figsize=(10, 5 * num_images))

    with torch.no_grad():
          for images, ages, races, genders in loader:
            if image_count >= num_images:
#         for idx, (images, ages, races, genders) in enumerate(loader):
#             if idx == num_images:
                break

            images = images.float().to(device)
            age_preds, race_preds, gender_preds = model(images)

            _, predicted_races = torch.max(race_preds, 1)
            _, predicted_genders = torch.max(gender_preds, 1)

            for i in range(images.size(0)):
                if image_count >= num_images:
                    break
            # Convert the predictions back to the label names
            pred_age = int(age_preds[i].squeeze().item() * max_age)
            true_age = int(ages[i].item() * max_age)

            # Assuming you have a reverse dictionary to map from label ID back to race name
#             pred_race = REVERSE_RACE_ID_MAP[predicted_races.item()]  
#             true_race = REVERSE_RACE_ID_MAP[torch.argmax(races, dim=1).item()]

            pred_race = ID_RACE_MAP[predicted_races[i].item()]
            true_race = ID_RACE_MAP[torch.argmax(races[i], dim=0).item()]


#             pred_gender = "Male" if predicted_genders.item() == 1 else "Female"
#             true_gender = "Male" if torch.argmax(genders, dim=1).item() == 1 else "Female"
            pred_gender = "Female" if predicted_genders[i].item() == 1 else "Male"
            true_gender = "Female" if torch.argmax(genders[i], dim=0).item() == 1 else "Male"
                
            # Plotting the image with predictions and true labels
#             axs[idx].imshow(np.transpose(images[0].cpu().numpy(), (1, 2, 0)))
#             axs[idx].axis('off')
#             axs[idx].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
            axs[image_count].imshow(np.transpose(images[i].cpu().numpy(), (1, 2, 0)))
            axs[image_count].axis('off')
            axs[image_count].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
                
            image_count += 1

    plt.tight_layout()
    plt.show()

# Visualize the predictions on the validation dataset
visualize_predictions(model, valid_loader)

# %%
from sklearn.metrics import classification_report,mean_squared_error, mean_absolute_error

# Lists to store true labels and predictions
true_ages, pred_ages = [], []
true_races, pred_races = [], []
true_genders, pred_genders = [], []

# Set the model to evaluation mode
model.eval()

# Disable gradient computation
with torch.no_grad():
    for images, ages, races, genders in valid_loader:  # Assuming you have a validation loader called 'val_loader'
        images = images.float().to(device)

        # Get predictions
        age_preds, race_preds, gender_preds = model(images)

        # Convert predictions to class labels
        _, predicted_races = torch.max(race_preds, 1)
        _, predicted_genders = torch.max(gender_preds, 1)

        # Append true labels and predicted labels
        true_ages.extend(ages.cpu().numpy())
        pred_ages.extend(age_preds.squeeze(1).cpu().numpy())

        true_races.extend(torch.argmax(races, dim=1).cpu().numpy())
        pred_races.extend(predicted_races.cpu().numpy())

        true_genders.extend(torch.argmax(genders, dim=1).cpu().numpy())
        pred_genders.extend(predicted_genders.cpu().numpy())

# Generate classification reports
print("Classification report for Age:")
# For regression task like Age, you might want to compute other metrics like MAE or MSE instead of classification report
# For demonstration, I'm just printing the first 10 true and predicted ages
print("True Ages:", true_ages[:10])
print("Predicted Ages:", pred_ages[:10])

# print("\nClassification report for Ages:")
# print(classification_report(true_ages, pred_ages))

# Report for Age:
print("Report for Age:")
mae = mean_absolute_error(true_ages, pred_ages)
mse = mean_squared_error(true_ages, pred_ages)
print(f"Mean Absolute Error for Age: {mae:.4f}")
print(f"Mean Squared Error for Age: {mse:.4f}")

print("\nClassification report for Race:")
print(classification_report(true_races, pred_races))

print("\nClassification report for Gender:")
print(classification_report(true_genders, pred_genders))
# Out:
# Classification report for Age:
# True Ages: [0.463768115942029, 0.34782608695652173, 0.34782608695652173, 0.5362318840579711, 0.8260869565217391, 0.4492753623188406, 0.7681159420289855, 0.6086956521739131, 0.2028985507246377, 0.37681159420289856]
# Predicted Ages: [0.49641046, 0.4969186, 0.49628207, 0.49678993, 0.496926, 0.49641833, 0.49610624, 0.4968665, 0.4971992, 0.49673933]
# Report for Age:
# Mean Absolute Error for Age: 0.1562
# Mean Squared Error for Age: 0.0378
#
# Classification report for Race:
#               precision    recall  f1-score   support
#
#            0       0.35      1.00      0.52      2340
#            1       0.00      0.00      0.00      1605
#            2       0.00      0.00      0.00       896
#            3       0.00      0.00      0.00      1340
#            4       0.00      0.00      0.00       498
#
#     accuracy                           0.35      6679
#    macro avg       0.07      0.20      0.10      6679
# weighted avg       0.12      0.35      0.18      6679
#
#
# Classification report for Gender:
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.70      3562
#            1       0.00      0.00      0.00      3117
#
#     accuracy                           0.53      6679
#    macro avg       0.27      0.50      0.35      6679
# weighted avg       0.28      0.53      0.37      6679
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_predictions(model, loader, num_images=5):
    model.eval()
    image_count = 0
    fig, axs = plt.subplots(num_images, figsize=(10, 5 * num_images))

    with torch.no_grad():
          for images, ages, races, genders in loader:
            if image_count >= num_images:
#         for idx, (images, ages, races, genders) in enumerate(loader):
#             if idx == num_images:
                break

            images = images.float().to(device)
            age_preds, race_preds, gender_preds = model(images)

            _, predicted_races = torch.max(race_preds, 1)
            _, predicted_genders = torch.max(gender_preds, 1)

            for i in range(images.size(0)):
                if image_count >= num_images:
                    break
            # Convert the predictions back to the label names
            pred_age = int(age_preds[i].squeeze().item() * max_age)
            true_age = int(ages[i].item() * max_age)

            # Assuming you have a reverse dictionary to map from label ID back to race name
#             pred_race = REVERSE_RACE_ID_MAP[predicted_races.item()]  
#             true_race = REVERSE_RACE_ID_MAP[torch.argmax(races, dim=1).item()]

            pred_race = ID_RACE_MAP[predicted_races[i].item()]
            true_race = ID_RACE_MAP[torch.argmax(races[i], dim=0).item()]


#             pred_gender = "Male" if predicted_genders.item() == 1 else "Female"
#             true_gender = "Male" if torch.argmax(genders, dim=1).item() == 1 else "Female"
            pred_gender = "Female" if predicted_genders[i].item() == 1 else "Male"
            true_gender = "Female" if torch.argmax(genders[i], dim=0).item() == 1 else "Male"
                
            # Plotting the image with predictions and true labels
#             axs[idx].imshow(np.transpose(images[0].cpu().numpy(), (1, 2, 0)))
#             axs[idx].axis('off')
#             axs[idx].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
            axs[image_count].imshow(np.transpose(images[i].cpu().numpy(), (1, 2, 0)))
            axs[image_count].axis('off')
            axs[image_count].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
                
            image_count += 1

    plt.tight_layout()
    plt.show()

# Visualize the predictions on the validation dataset
visualize_predictions(model, valid_loader)

# %%
class UTKFaceDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_name = self.df.iloc[idx, 3]
        image = Image.open(img_name)
        age = self.df.iloc[idx, 0] / max_age
        race = torch.zeros(len(RACE_ID_MAP))
        race[self.df.iloc[idx, 5]] = 1
        gender = torch.zeros(2)
        gender[self.df.iloc[idx, 4]] = 1

        if self.transform:
            image = self.transform(image)

        return image, age, race, gender

transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.5),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = UTKFaceDataset(df, transform)

train_loader = DataLoader(dataset, batch_size=64, sampler=SubsetRandomSampler(train_idx))
valid_loader = DataLoader(dataset, batch_size=64, sampler=SubsetRandomSampler(valid_idx))
test_loader = DataLoader(dataset, batch_size=128, sampler=SubsetRandomSampler(test_idx))

# %%
class MobileNetV2Model(nn.Module):
    def __init__(self):
        super(MobileNetV3Model, self).__init__()
        
        # MobileNet V2 backbone
        self.backbone = models.mobilenet_v2_small(pretrained=True)
        self.backbone = nn.Sequential(*list(self.backbone.children())[:-1])

        # Extra CNN layers for age
        self.age_cnn = nn.Sequential(
            self.conv_block(576, 192),
            self.conv_block(192, 128),
            self.conv_block(128, 64),
#             nn.MaxPool2d(2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc1_age = nn.Sequential(
            nn.Linear(64, 128), 
            nn.ReLU(), 
            nn.Linear(128, 1)
        )

        # Extra CNN layers for race (ethnicity)
        self.race_cnn = nn.Sequential(
            self.conv_block(576, 192),
#             nn.MaxPool2d(2),
            self.conv_block(192, 128),
#             nn.MaxPool2d(2),
            self.conv_block(128, 64),
#             nn.MaxPool2d(2),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc1_race = nn.Sequential(
            nn.Linear(64, 256),
            nn.ReLU(),
            nn.Dropout(0.35),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.35),
            nn.Linear(128, len(RACE_ID_MAP))
        )

        # Extra CNN layers for gender
        self.gender_cnn = nn.Sequential(
            self.conv_block(576, 192),
            self.conv_block(192, 128),
            self.conv_block(128, 64),
#             nn.MaxPool2d(2),
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.fc1_gender = nn.Sequential(
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(0.43),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.43),
            nn.Linear(64, 2)
        )

    def conv_block(self, in_channels, out_channels):
        layers = [
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
#             nn.AdaptiveAvgPool2d((1,1))
        ]
        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.backbone(x)
# #         print("Shape after backbone:", x.shape)
#         age_x = self.age_cnn[0](x)
#         print("Shape after first conv_block in age_cnn:", age_x.shape)
    
#         age_x = self.age_cnn[1](age_x)
#         print("Shape after second conv_block in age_cnn:", age_x.shape)
    
#         age_x = self.age_cnn[2](age_x)
#         print("Shape after third conv_block in age_cnn:", age_x.shape)
    
#         age_x = self.age_cnn[3](age_x)
#         print("Shape after MaxPool2d in age_cnn:", age_x.shape)
    
#         age_x = self.age_cnn[4](age_x)
#         print("Shape after BatchNorm2d in age_cnn:", age_x.shape)

#         age_x = self.age_cnn[5](age_x)
#         print("Shape after ReLU in age_cnn:", age_x.shape)
    
#         age_x = self.age_cnn[6](age_x)
#         print("Shape after AdaptiveAvgPool2d in age_cnn:", age_x.shape)
        age_x = self.age_cnn(x)
        age_x = torch.flatten(age_x, 1)
        age = torch.sigmoid(self.fc1_age(age_x))
        
        race_x = self.race_cnn(x)
        race_x = torch.flatten(race_x, 1)
        race = F.softmax(self.fc1_race(race_x), dim=1)
        
        gender_x = self.gender_cnn(x)
        gender_x = torch.flatten(gender_x, 1)
        gender = torch.sigmoid(self.fc1_gender(gender_x))#,dim=1)
        
        return age, race, gender

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model =  MobileNetV3Model().to(device)
model = model.float()
criterion_age = nn.MSELoss()
criterion_race = nn.CrossEntropyLoss()      #loss together backward or individually backward
criterion_gender = nn.CrossEntropyLoss()
# optimizer = torch.optim.RMSprop(model.parameters(),lr=0.0001)
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████| 9.83M/9.83M [00:00<00:00, 115MB/s]

# %%
import time
# Initialization
num_epochs = 100

# Lists to hold running losses for plotting
running_loss_age = []
running_loss_race = []
running_loss_gender = []
running_total_loss = []

# Start the timer
start_time = time.time()

for epoch in range(num_epochs):
    model.train()
    epoch_loss_age = 0
    epoch_loss_race = 0
    epoch_loss_gender = 0
    epoch_total_loss = 0
    total_samples = 0
    
    for images, ages, races, genders in train_loader:
#         print(images.shape)
        images, ages, races, genders = images.float().to(device), ages.float().to(device), races.float().to(device), genders.float().to(device)
        
        optimizer.zero_grad()
        age_preds, race_preds, gender_preds = model(images)
#         print(age_preds.shape)
#         print(race_preds.shape)
#         print(gender_preds.shape)
        age_preds = age_preds.squeeze(1)
        loss_age = criterion_age(age_preds, ages)
        loss_race = criterion_race(race_preds, torch.argmax(races, dim=1))
        loss_gender = criterion_gender(gender_preds, torch.argmax(genders, dim=1))
        loss = 2*loss_age + 1.5*loss_race + loss_gender  #Why are these values being multiplied?
        loss = loss.float()
        #print(loss)
        loss.backward()
        optimizer.step()
        
        # Update the running losses
        epoch_loss_age += loss_age.item() * len(images)
        epoch_loss_race += loss_race.item() * len(images)
        epoch_loss_gender += loss_gender.item() * len(images)
        epoch_total_loss += loss.item() * len(images)
        total_samples += len(images)
        
    # Average the losses over the epoch
    avg_loss_age = epoch_loss_age / total_samples
    avg_loss_race = epoch_loss_race / total_samples
    avg_loss_gender = epoch_loss_gender / total_samples
    avg_total_loss = epoch_total_loss / total_samples

    # Append the average losses for plotting later
    running_loss_age.append(avg_loss_age)
    running_loss_race.append(avg_loss_race)
    running_loss_gender.append(avg_loss_gender)
    running_total_loss.append(avg_total_loss)

    # Print out the losses

    print(f"Epoch [{epoch+1}/{num_epochs}] => Age Loss: {avg_loss_age:.9f}, Race Loss: {avg_loss_race:.9f}, Gender Loss: {avg_loss_gender:.9f}, Total Loss: {avg_total_loss:.9f}")

# End the timer
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Training took {elapsed_time:.2f} seconds")
    
#Save the trained model's parameters
# Out:
# Epoch [1/100] => Age Loss: 0.023768769, Race Loss: 1.446210684, Gender Loss: 0.593552748, Total Loss: 2.810406303
# Epoch [2/100] => Age Loss: 0.017963875, Race Loss: 1.301878671, Gender Loss: 0.420938564, Total Loss: 2.409684327
# Epoch [3/100] => Age Loss: 0.016699840, Race Loss: 1.211974235, Gender Loss: 0.396503254, Total Loss: 2.247864301
# Epoch [4/100] => Age Loss: 0.015353474, Race Loss: 1.168562489, Gender Loss: 0.387500789, Total Loss: 2.171051471
# Epoch [5/100] => Age Loss: 0.014608488, Race Loss: 1.148667676, Gender Loss: 0.380601690, Total Loss: 2.132820176
# Epoch [6/100] => Age Loss: 0.013938750, Race Loss: 1.140285169, Gender Loss: 0.378877869, Total Loss: 2.117183127
# Epoch [7/100] => Age Loss: 0.013287527, Race Loss: 1.132393167, Gender Loss: 0.374631690, Total Loss: 2.099796490
# Epoch [8/100] => Age Loss: 0.013029455, Race Loss: 1.125697756, Gender Loss: 0.372375273, Total Loss: 2.086980814
# Epoch [9/100] => Age Loss: 0.012469916, Race Loss: 1.117142551, Gender Loss: 0.369627078, Total Loss: 2.070280736
# Epoch [10/100] => Age Loss: 0.012233372, Race Loss: 1.111258019, Gender Loss: 0.366372339, Total Loss: 2.057726117
# Epoch [11/100] => Age Loss: 0.011772491, Race Loss: 1.114795695, Gender Loss: 0.363929336, Total Loss: 2.059667862
# Epoch [12/100] => Age Loss: 0.011503521, Race Loss: 1.106975357, Gender Loss: 0.365196673, Total Loss: 2.048666747
# Epoch [13/100] => Age Loss: 0.011086990, Race Loss: 1.103544922, Gender Loss: 0.362824377, Total Loss: 2.040315736
# Epoch [14/100] => Age Loss: 0.010686788, Race Loss: 1.098394714, Gender Loss: 0.361517994, Total Loss: 2.030483633
# Epoch [15/100] => Age Loss: 0.010695615, Race Loss: 1.097346788, Gender Loss: 0.359606565, Total Loss: 2.027017980
# Epoch [16/100] => Age Loss: 0.010265137, Race Loss: 1.090237268, Gender Loss: 0.358237842, Total Loss: 2.014124025
# Epoch [17/100] => Age Loss: 0.009899556, Race Loss: 1.088541306, Gender Loss: 0.355208322, Total Loss: 2.007819396
# Epoch [18/100] => Age Loss: 0.009900429, Race Loss: 1.085776847, Gender Loss: 0.355469463, Total Loss: 2.003935589
# Epoch [19/100] => Age Loss: 0.009641303, Race Loss: 1.084187444, Gender Loss: 0.357013863, Total Loss: 2.002577641
# Epoch [20/100] => Age Loss: 0.009342025, Race Loss: 1.084720075, Gender Loss: 0.354635898, Total Loss: 2.000400063
# Epoch [21/100] => Age Loss: 0.009135710, Race Loss: 1.080242904, Gender Loss: 0.352305697, Total Loss: 1.990941475
# Epoch [22/100] => Age Loss: 0.008909686, Race Loss: 1.077800311, Gender Loss: 0.351933452, Total Loss: 1.986453292
# Epoch [23/100] => Age Loss: 0.008777931, Race Loss: 1.076141192, Gender Loss: 0.349911797, Total Loss: 1.981679451
# Epoch [24/100] => Age Loss: 0.008672657, Race Loss: 1.072744026, Gender Loss: 0.350121010, Total Loss: 1.976582361
# Epoch [25/100] => Age Loss: 0.008449285, Race Loss: 1.070764876, Gender Loss: 0.348884018, Total Loss: 1.971929901
# Epoch [26/100] => Age Loss: 0.008198940, Race Loss: 1.069362137, Gender Loss: 0.349194509, Total Loss: 1.969635596
# Epoch [27/100] => Age Loss: 0.008387221, Race Loss: 1.067482250, Gender Loss: 0.348642729, Total Loss: 1.966640549
# Epoch [28/100] => Age Loss: 0.007967546, Race Loss: 1.067104181, Gender Loss: 0.346220839, Total Loss: 1.962812199
# Epoch [29/100] => Age Loss: 0.007706364, Race Loss: 1.064100642, Gender Loss: 0.346294608, Total Loss: 1.957858301
# Epoch [30/100] => Age Loss: 0.007715610, Race Loss: 1.064037839, Gender Loss: 0.346694480, Total Loss: 1.958182456
# Epoch [31/100] => Age Loss: 0.007522438, Race Loss: 1.062962881, Gender Loss: 0.345819318, Total Loss: 1.955308515
# Epoch [32/100] => Age Loss: 0.007334254, Race Loss: 1.060521584, Gender Loss: 0.345004813, Total Loss: 1.950455696
# Epoch [33/100] => Age Loss: 0.007418399, Race Loss: 1.058840901, Gender Loss: 0.345357969, Total Loss: 1.948456115
# Epoch [34/100] => Age Loss: 0.007127159, Race Loss: 1.059226356, Gender Loss: 0.343920643, Total Loss: 1.947014502
# Epoch [35/100] => Age Loss: 0.007057521, Race Loss: 1.055648149, Gender Loss: 0.344876435, Total Loss: 1.942463704
# Epoch [36/100] => Age Loss: 0.007158325, Race Loss: 1.054038207, Gender Loss: 0.342690440, Total Loss: 1.938064401
# Epoch [37/100] => Age Loss: 0.006803245, Race Loss: 1.051783794, Gender Loss: 0.342822414, Total Loss: 1.934104595
# Epoch [38/100] => Age Loss: 0.006658085, Race Loss: 1.050560990, Gender Loss: 0.340195540, Total Loss: 1.929353202
# Epoch [39/100] => Age Loss: 0.006620727, Race Loss: 1.049142374, Gender Loss: 0.343086747, Total Loss: 1.930041763
# Epoch [40/100] => Age Loss: 0.006615949, Race Loss: 1.045331764, Gender Loss: 0.343908995, Total Loss: 1.925138546
# Epoch [41/100] => Age Loss: 0.006420727, Race Loss: 1.045374667, Gender Loss: 0.340512071, Total Loss: 1.921415521
# Epoch [42/100] => Age Loss: 0.006223144, Race Loss: 1.041451126, Gender Loss: 0.340399394, Total Loss: 1.915022368
# Epoch [43/100] => Age Loss: 0.006166280, Race Loss: 1.041956109, Gender Loss: 0.338962049, Total Loss: 1.914228769
# Epoch [44/100] => Age Loss: 0.006142818, Race Loss: 1.040631231, Gender Loss: 0.337608378, Total Loss: 1.910840866
# Epoch [45/100] => Age Loss: 0.006092646, Race Loss: 1.038069812, Gender Loss: 0.338874520, Total Loss: 1.908164529
# Epoch [46/100] => Age Loss: 0.006083760, Race Loss: 1.036447897, Gender Loss: 0.337347443, Total Loss: 1.904186803
# Epoch [47/100] => Age Loss: 0.006006870, Race Loss: 1.032610020, Gender Loss: 0.338122725, Total Loss: 1.899051489
# Epoch [48/100] => Age Loss: 0.005839221, Race Loss: 1.035406346, Gender Loss: 0.337612660, Total Loss: 1.902400627
# Epoch [49/100] => Age Loss: 0.005914946, Race Loss: 1.033167737, Gender Loss: 0.338783330, Total Loss: 1.900364822
# Epoch [50/100] => Age Loss: 0.005819951, Race Loss: 1.031650954, Gender Loss: 0.338984086, Total Loss: 1.898100421
# Epoch [51/100] => Age Loss: 0.005714754, Race Loss: 1.026051915, Gender Loss: 0.338594680, Total Loss: 1.889102069
# Epoch [52/100] => Age Loss: 0.005557496, Race Loss: 1.028232268, Gender Loss: 0.336101118, Total Loss: 1.889564519
# Epoch [53/100] => Age Loss: 0.005644434, Race Loss: 1.025229833, Gender Loss: 0.337459972, Total Loss: 1.886593595
# Epoch [54/100] => Age Loss: 0.005478345, Race Loss: 1.025199298, Gender Loss: 0.335647116, Total Loss: 1.884402757
# Epoch [55/100] => Age Loss: 0.005416631, Race Loss: 1.020401217, Gender Loss: 0.336142810, Total Loss: 1.877577898
# Epoch [56/100] => Age Loss: 0.005384481, Race Loss: 1.018351345, Gender Loss: 0.335463598, Total Loss: 1.873759578
# Epoch [57/100] => Age Loss: 0.005272878, Race Loss: 1.019924817, Gender Loss: 0.335594225, Total Loss: 1.876027200
# Epoch [58/100] => Age Loss: 0.005269440, Race Loss: 1.021892079, Gender Loss: 0.335799632, Total Loss: 1.879176639
# Epoch [59/100] => Age Loss: 0.005275657, Race Loss: 1.020563264, Gender Loss: 0.334018700, Total Loss: 1.875414916
# Epoch [60/100] => Age Loss: 0.005057793, Race Loss: 1.016326306, Gender Loss: 0.333898564, Total Loss: 1.868503608
# Epoch [61/100] => Age Loss: 0.005278958, Race Loss: 1.015126950, Gender Loss: 0.336029808, Total Loss: 1.869278149
# Epoch [62/100] => Age Loss: 0.005222276, Race Loss: 1.012407136, Gender Loss: 0.335050315, Total Loss: 1.864105569
# Epoch [63/100] => Age Loss: 0.004950862, Race Loss: 1.012276079, Gender Loss: 0.333287227, Total Loss: 1.861603070
# Epoch [64/100] => Age Loss: 0.005010830, Race Loss: 1.012543713, Gender Loss: 0.333068368, Total Loss: 1.861905598
# Epoch [65/100] => Age Loss: 0.005042417, Race Loss: 1.007536357, Gender Loss: 0.332370892, Total Loss: 1.853760262
# Epoch [66/100] => Age Loss: 0.004889428, Race Loss: 1.009865745, Gender Loss: 0.333940772, Total Loss: 1.858518246
# Epoch [67/100] => Age Loss: 0.004781269, Race Loss: 1.006207888, Gender Loss: 0.332149191, Total Loss: 1.851023561
# Epoch [68/100] => Age Loss: 0.004924490, Race Loss: 1.006782290, Gender Loss: 0.333638166, Total Loss: 1.853660579
# Epoch [69/100] => Age Loss: 0.004711150, Race Loss: 1.006333421, Gender Loss: 0.331879602, Total Loss: 1.850802030
# Epoch [70/100] => Age Loss: 0.004632389, Race Loss: 1.006391106, Gender Loss: 0.332086884, Total Loss: 1.850938321
# Epoch [71/100] => Age Loss: 0.004678603, Race Loss: 1.004332113, Gender Loss: 0.333091542, Total Loss: 1.848946911
# Epoch [72/100] => Age Loss: 0.004640328, Race Loss: 1.003337320, Gender Loss: 0.333181885, Total Loss: 1.847468511
# Epoch [73/100] => Age Loss: 0.004455968, Race Loss: 1.003212722, Gender Loss: 0.332471316, Total Loss: 1.846202335
# Epoch [74/100] => Age Loss: 0.004661125, Race Loss: 0.999811101, Gender Loss: 0.331921446, Total Loss: 1.840960340
# Epoch [75/100] => Age Loss: 0.004530262, Race Loss: 1.001992224, Gender Loss: 0.331734666, Total Loss: 1.843783522
# Epoch [76/100] => Age Loss: 0.004456942, Race Loss: 0.997714926, Gender Loss: 0.331071977, Total Loss: 1.836558248
# Epoch [77/100] => Age Loss: 0.004547019, Race Loss: 1.003842673, Gender Loss: 0.330241488, Total Loss: 1.845099534
# Epoch [78/100] => Age Loss: 0.004427505, Race Loss: 0.996086937, Gender Loss: 0.332478420, Total Loss: 1.835463830
# Epoch [79/100] => Age Loss: 0.004628539, Race Loss: 0.998399811, Gender Loss: 0.331910911, Total Loss: 1.838767698
# Epoch [80/100] => Age Loss: 0.004376920, Race Loss: 0.995880871, Gender Loss: 0.330719095, Total Loss: 1.833294253
# Epoch [81/100] => Age Loss: 0.004214603, Race Loss: 0.996036078, Gender Loss: 0.329876617, Total Loss: 1.832359939
# Epoch [82/100] => Age Loss: 0.004459745, Race Loss: 0.996363584, Gender Loss: 0.331315711, Total Loss: 1.834780578
# Epoch [83/100] => Age Loss: 0.004336308, Race Loss: 0.994381838, Gender Loss: 0.332339187, Total Loss: 1.832584562
# Epoch [84/100] => Age Loss: 0.004302838, Race Loss: 0.995095087, Gender Loss: 0.331626395, Total Loss: 1.832874695
# Epoch [85/100] => Age Loss: 0.004136045, Race Loss: 0.994156974, Gender Loss: 0.330783029, Total Loss: 1.830290577
# Epoch [86/100] => Age Loss: 0.004195978, Race Loss: 0.993032422, Gender Loss: 0.331022088, Total Loss: 1.828962684
# Epoch [87/100] => Age Loss: 0.004136149, Race Loss: 0.995131299, Gender Loss: 0.329895194, Total Loss: 1.830864436
# Epoch [88/100] => Age Loss: 0.004206787, Race Loss: 0.990737258, Gender Loss: 0.330577303, Total Loss: 1.825096765
# Epoch [89/100] => Age Loss: 0.004283561, Race Loss: 0.987914318, Gender Loss: 0.330211528, Total Loss: 1.820650132
# Epoch [90/100] => Age Loss: 0.004040614, Race Loss: 0.986379464, Gender Loss: 0.329055473, Total Loss: 1.816705892
# Epoch [91/100] => Age Loss: 0.004059259, Race Loss: 0.991195566, Gender Loss: 0.329534861, Total Loss: 1.824446729
# Epoch [92/100] => Age Loss: 0.004108136, Race Loss: 0.986451831, Gender Loss: 0.329044265, Total Loss: 1.816938282
# Epoch [93/100] => Age Loss: 0.003988056, Race Loss: 0.985010239, Gender Loss: 0.330251258, Total Loss: 1.815742731
# Epoch [94/100] => Age Loss: 0.004006946, Race Loss: 0.987921344, Gender Loss: 0.329862751, Total Loss: 1.819758670
# Epoch [95/100] => Age Loss: 0.004039866, Race Loss: 0.987055577, Gender Loss: 0.330367628, Total Loss: 1.819030725
# Epoch [96/100] => Age Loss: 0.003803516, Race Loss: 0.983813468, Gender Loss: 0.328969637, Total Loss: 1.812296871
# Epoch [97/100] => Age Loss: 0.003794071, Race Loss: 0.981576170, Gender Loss: 0.329382832, Total Loss: 1.809335221
# Epoch [98/100] => Age Loss: 0.003849116, Race Loss: 0.985456302, Gender Loss: 0.329482093, Total Loss: 1.815364779
# Epoch [99/100] => Age Loss: 0.003803479, Race Loss: 0.983771972, Gender Loss: 0.328958400, Total Loss: 1.812223315
# Epoch [100/100] => Age Loss: 0.003763422, Race Loss: 0.981647311, Gender Loss: 0.329999084, Total Loss: 1.809996894
# Training took 9844.12 seconds

# %%
# Plotting the loss curves

plt.figure(figsize=(12, 8))

# Age Loss curve
plt.plot(running_loss_age, label='Age Loss', color='blue')
# Race Loss curve
plt.plot(running_loss_race, label='Race Loss', color='green')
# Gender Loss curve
plt.plot(running_loss_gender, label='Gender Loss', color='red')
# Total Loss curve
plt.plot(running_total_loss, label='Total Loss', color='black')

# Setting x and y axis labels
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curves')

# Displaying the legend
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# model_directory = "/kaggle/working/Multitask_MobileNet_v3_augmentations_applied/"
# os.makedirs(model_directory, exist_ok = True)

# model_path = model_directory+"model_weights.pt"
# torch.save(model, model_path)

# %%
from sklearn.metrics import classification_report, mean_absolute_error, mean_squared_error

# Lists to store true labels and predictions
true_ages, pred_ages = [], []
true_races, pred_races = [], []
true_genders, pred_genders = [], []

# Set the model to evaluation mode
model.eval()

# Disable gradient computation
with torch.no_grad():
    for images, ages, races, genders in valid_loader:  # Assuming you have a validation loader called 'val_loader'
        images = images.float().to(device)

        # Get predictions
        age_preds, race_preds, gender_preds = model(images)

        # Convert predictions to class labels
        _, predicted_races = torch.max(race_preds, 1)
        _, predicted_genders = torch.max(gender_preds, 1)

        # Append true labels and predicted labels
        true_ages.extend(ages.cpu().numpy())
        pred_ages.extend(age_preds.squeeze(1).cpu().numpy())

        true_races.extend(torch.argmax(races, dim=1).cpu().numpy())
        pred_races.extend(predicted_races.cpu().numpy())

        true_genders.extend(torch.argmax(genders, dim=1).cpu().numpy())
        pred_genders.extend(predicted_genders.cpu().numpy())

# Generate classification reports
print("Classification report for Age:")
# For regression task like Age, you might want to compute other metrics like MAE or MSE instead of classification report
# For demonstration, I'm just printing the first 10 true and predicted ages
print("True Ages:", true_ages[:10])
print("Predicted Ages:", pred_ages[:10])

# print("\nClassification report for Age:")
# print(classification_report(true_ages, pred_ages))

# Report for Age:
print("Report for Age:")
mae = mean_absolute_error(true_ages, pred_ages)
mse = mean_squared_error(true_ages, pred_ages)
print(f"Mean Absolute Error for Age: {mae:.4f}")
print(f"Mean Squared Error for Age: {mse:.4f}")

print("\nClassification report for Race:")
print(classification_report(true_races, pred_races))

print("\nClassification report for Gender:")
print(classification_report(true_genders, pred_genders))
# Out:
# Classification report for Age:
# True Ages: [0.3333333333333333, 0.5072463768115942, 0.2318840579710145, 0.7246376811594203, 0.782608695652174, 0.5072463768115942, 0.391304347826087, 0.6086956521739131, 0.30434782608695654, 0.4057971014492754]
# Predicted Ages: [0.38901547, 0.31700835, 0.19243234, 0.7230309, 0.79904866, 0.3745778, 0.39347816, 0.6860549, 0.5492048, 0.3675592]
# Report for Age:
# Mean Absolute Error for Age: 0.0713
# Mean Squared Error for Age: 0.0097
#
# Classification report for Race:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      2308
#            1       0.88      0.94      0.91      1592
#            2       0.87      0.90      0.89       903
#            3       0.87      0.77      0.82      1356
#            4       0.59      0.43      0.49       520
#
#     accuracy                           0.85      6679
#    macro avg       0.81      0.79      0.79      6679
# weighted avg       0.84      0.85      0.84      6679
#
#
# Classification report for Gender:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      3544
#            1       0.97      0.95      0.96      3135
#
#     accuracy                           0.96      6679
#    macro avg       0.96      0.96      0.96      6679
# weighted avg       0.96      0.96      0.96      6679

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize_predictions(model, loader, num_images=5):
    model.eval()
    image_count = 0
    fig, axs = plt.subplots(num_images, figsize=(10, 5 * num_images))

    with torch.no_grad():
          for images, ages, races, genders in loader:
            if image_count >= num_images:
#         for idx, (images, ages, races, genders) in enumerate(loader):
#             if idx == num_images:
                break

            images = images.float().to(device)
            age_preds, race_preds, gender_preds = model(images)

            _, predicted_races = torch.max(race_preds, 1)
            _, predicted_genders = torch.max(gender_preds, 1)

            for i in range(images.size(0)):
                if image_count >= num_images:
                    break
            # Convert the predictions back to the label names
            pred_age = int(age_preds[i].squeeze().item() * max_age)
            true_age = int(ages[i].item() * max_age)

            # Assuming you have a reverse dictionary to map from label ID back to race name
#             pred_race = REVERSE_RACE_ID_MAP[predicted_races.item()]  
#             true_race = REVERSE_RACE_ID_MAP[torch.argmax(races, dim=1).item()]

            pred_race = ID_RACE_MAP[predicted_races[i].item()]
            true_race = ID_RACE_MAP[torch.argmax(races[i], dim=0).item()]


#             pred_gender = "Male" if predicted_genders.item() == 1 else "Female"
#             true_gender = "Male" if torch.argmax(genders, dim=1).item() == 1 else "Female"
            pred_gender = "Female" if predicted_genders[i].item() == 1 else "Male"
            true_gender = "Female" if torch.argmax(genders[i], dim=0).item() == 1 else "Male"
                
            # Plotting the image with predictions and true labels
#             axs[idx].imshow(np.transpose(images[0].cpu().numpy(), (1, 2, 0)))
#             axs[idx].axis('off')
#             axs[idx].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
            axs[image_count].imshow(np.transpose(images[i].cpu().numpy(), (1, 2, 0)))
            axs[image_count].axis('off')
            axs[image_count].set_title(f"True: {true_age} years, {true_race}, {true_gender}\nPred: {pred_age} years, {pred_race}, {pred_gender}")
                
            image_count += 1

    plt.tight_layout()
    plt.show()

# Visualize the predictions on the validation dataset
visualize_predictions(model, valid_loader)
